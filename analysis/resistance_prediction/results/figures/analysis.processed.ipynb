# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/hps/software/users/iqbal/mbhall/miniconda3/envs/h2h/lib/python3.8/site-packages', '/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/workflow/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x08\x00\x01\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c@/hps/nobackup/iqbal/mbhall/tech_wars/data/QC/report/coverage.csv\x94\x8c\x19../../docs/phenotypes.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-7.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-7.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-7.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-7.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_109.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_109.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_109.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_109.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-28.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-28.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-28.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-28.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_135.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_135.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_135.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_135.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-43.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-43.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-43.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-43.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-31.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-31.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-31.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-31.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-50.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-50.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-50.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-50.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_110.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_110.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_110.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_110.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-1.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-1.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-1.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-1.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-22.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-22.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-22.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-22.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-36.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-36.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-36.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-36.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_120.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_120.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_120.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_120.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_107.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_107.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_107.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_107.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-51.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-51.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-51.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-51.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-6.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-6.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-6.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-6.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-53.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-53.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-53.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-53.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_130.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_130.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_130.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_130.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-34.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-34.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-34.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-34.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-40.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-40.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-40.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-40.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_143.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_143.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_143.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_143.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-25.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-25.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-25.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-25.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-30.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-30.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-30.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-30.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-33.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-33.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-33.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-33.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_111.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_111.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_111.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_111.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_102.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_102.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_102.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_102.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-48.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-48.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-48.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-48.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-47.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-47.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-47.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-47.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_116.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_116.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_116.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_116.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_150.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_150.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_150.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_150.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-39.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-39.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-39.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-39.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-44.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-44.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-44.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-44.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_132.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_132.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_132.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_132.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_128.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_128.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_128.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_128.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-46.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-46.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-46.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-46.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_112.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_112.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_112.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_112.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-12.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-12.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-12.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-12.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_154.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_154.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_154.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_154.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_126.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_126.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_126.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_126.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-5.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-5.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-5.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-5.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_122.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_122.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_122.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_122.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_133.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_133.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_133.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_133.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-16.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-16.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-16.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-16.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_140.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_140.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_140.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_140.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_134.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_134.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_134.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_134.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_123.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_123.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_123.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_123.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-42.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-42.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-42.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-42.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_127.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_127.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_127.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_127.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_117.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_117.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_117.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_117.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-1.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-1.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-1.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-1.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_124.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_124.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_124.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_124.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_151.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_151.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_151.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_151.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_139.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_139.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_139.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_139.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_121.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_121.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_121.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_121.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_113.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_113.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_113.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_113.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-18.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-18.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-18.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-18.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_131.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_131.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_131.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_131.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-38.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-38.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-38.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-38.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_104.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_104.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_104.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_104.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-46.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-46.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-46.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-46.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-25.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-25.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-25.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-25.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_129.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_129.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_129.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_129.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_118.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_118.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_118.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_118.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_136.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_136.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_136.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_136.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-50.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-50.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-50.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-50.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-11.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-11.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-11.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-11.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-41.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-41.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-41.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-41.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-2.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-2.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-2.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-2.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-19.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-19.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-19.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-19.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-10.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-10.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-10.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-10.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-3.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-3.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-3.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-3.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-8.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-8.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-8.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-8.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-15.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-15.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-15.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-15.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_105.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_105.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_105.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_105.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_125.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_125.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_125.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_125.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_144.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_144.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_144.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_144.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-21.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-21.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-21.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-21.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-14.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-14.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-14.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-14.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_141.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_141.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_141.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_141.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_103.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_103.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_103.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_103.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_115.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_115.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_115.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_115.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_137.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_137.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_137.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_137.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-17.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-17.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-17.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-17.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-13.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-13.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-13.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-13.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-20.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-20.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-20.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-20.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_142.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_142.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_142.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_142.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_148.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_148.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_148.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_148.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-54.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-54.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-54.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-54.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_106.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_106.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_106.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_106.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_1-32.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_1-32.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-32.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_1-32.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_2-53.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_2-53.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-53.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_2-53.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/madagascar/mada_152.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/madagascar/mada_152.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_152.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/madagascar/mada_152.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R26791.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R26791.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R26791.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R26791.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R21363.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R21363.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21363.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R21363.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R30234.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R30234.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30234.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R30234.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R36431.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R36431.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R36431.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R36431.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R27252.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R27252.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27252.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R27252.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R29816.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R29816.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R29816.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R29816.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R29598.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R29598.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R29598.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R29598.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R30078.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R30078.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30078.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R30078.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R24100.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R24100.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R24100.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R24100.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R31095.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R31095.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R31095.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R31095.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R18043.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R18043.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R18043.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R18043.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R18040.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R18040.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R18040.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R18040.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R27937.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R27937.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27937.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R27937.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R30396.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R30396.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30396.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R30396.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R27657.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R27657.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27657.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R27657.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R30420.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R30420.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30420.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R30420.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R21839.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R21839.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21839.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R21839.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R28182.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R28182.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28182.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R28182.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R20896.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R20896.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20896.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R20896.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R23887.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R23887.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23887.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R23887.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R37765.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R37765.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R37765.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R37765.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R30215.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R30215.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30215.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R30215.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R21893.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R21893.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21893.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R21893.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R27725.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R27725.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27725.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R27725.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R21408.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R21408.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21408.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R21408.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R28012.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R28012.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28012.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R28012.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R28703.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R28703.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28703.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R28703.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R21770.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R21770.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21770.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R21770.drprg.csv\x94\x95@[\x00\x00\x00\x00\x00\x00\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R20260.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R20260.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20260.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R20260.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R25048.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R25048.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R25048.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R25048.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R23146.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R23146.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23146.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R23146.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R32929.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R32929.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R32929.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R32929.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R23571.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R23571.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23571.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R23571.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R20574.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R20574.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20574.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R20574.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R28980.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R28980.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28980.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R28980.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R24120.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R24120.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R24120.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R24120.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R28581.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R28581.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28581.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R28581.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R15311.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R15311.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R15311.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R15311.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R22601.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R22601.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R22601.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R22601.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R20983.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R20983.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20983.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R20983.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/south_africa/R26778.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/south_africa/R26778.drprg.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R26778.mykrobe.csv\x94\x8c\x84/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/south_africa/R26778.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/17_616026.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/17_616026.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/17_616026.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/17_616026.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/17_616156.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/17_616156.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/17_616156.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/17_616156.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0621851.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0621851.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0621851.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0621851.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622057.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622057.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622057.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622057.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622158.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622158.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622158.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622158.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622224.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622224.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622224.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622224.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622267.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622267.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622267.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622267.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622291.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622291.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622291.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622291.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622300.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622300.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622300.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622300.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622312.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622312.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622312.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622312.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622363.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622363.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622363.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622363.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622365.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622365.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622365.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622365.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622431.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622431.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622431.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622431.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622434.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622434.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622434.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622434.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622446.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622446.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622446.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622446.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622455.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622455.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622455.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622455.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622456.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622456.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622456.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622456.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_0622465.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_0622465.drprg.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622465.mykrobe.csv\x94\x8c\x86/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_0622465.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/illumina/birmingham/18_620606.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/illumina/birmingham/18_620606.drprg.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_620606.mykrobe.csv\x94\x8c\x85/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/drprg/nanopore/birmingham/18_620606.drprg.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x08coverage\x94K\x00N\x86\x94\x8c\nphenosheet\x94K\x01N\x86\x94\x8c\x0bconcordance\x94K\x02M^\x02\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ejs\x02\x00\x00\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(jy\x02\x00\x00)}\x94\x8c\x05_name\x94js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bjk\x02\x00\x00h\njm\x02\x00\x00h\x0bjo\x02\x00\x00h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhchdhehfhghhhihjhkhlhmhnhohphqhrhshthuhvhwhxhyhzh{h|h}h~h\x7fh\x80h\x81h\x82h\x83h\x84h\x85h\x86h\x87h\x88h\x89h\x8ah\x8bh\x8ch\x8dh\x8eh\x8fh\x90h\x91h\x92h\x93h\x94h\x95h\x96h\x97h\x98h\x99h\x9ah\x9bh\x9ch\x9dh\x9eh\x9fh\xa0h\xa1h\xa2h\xa3h\xa4h\xa5h\xa6h\xa7h\xa8h\xa9h\xaah\xabh\xach\xadh\xaeh\xafh\xb0h\xb1h\xb2h\xb3h\xb4h\xb5h\xb6h\xb7h\xb8h\xb9h\xbah\xbbh\xbch\xbdh\xbeh\xbfh\xc0h\xc1h\xc2h\xc3h\xc4h\xc5h\xc6h\xc7h\xc8h\xc9h\xcah\xcbh\xcch\xcdh\xceh\xcfh\xd0h\xd1h\xd2h\xd3h\xd4h\xd5h\xd6h\xd7h\xd8h\xd9h\xdah\xdbh\xdch\xddh\xdeh\xdfh\xe0h\xe1h\xe2h\xe3h\xe4h\xe5h\xe6h\xe7h\xe8h\xe9h\xeah\xebh\xech\xedh\xeeh\xefh\xf0h\xf1h\xf2h\xf3h\xf4h\xf5h\xf6h\xf7h\xf8h\xf9h\xfah\xfbh\xfch\xfdh\xfeh\xffj\x00\x01\x00\x00j\x01\x01\x00\x00j\x02\x01\x00\x00j\x03\x01\x00\x00j\x04\x01\x00\x00j\x05\x01\x00\x00j\x06\x01\x00\x00j\x07\x01\x00\x00j\x08\x01\x00\x00j\t\x01\x00\x00j\n\x01\x00\x00j\x0b\x01\x00\x00j\x0c\x01\x00\x00j\r\x01\x00\x00j\x0e\x01\x00\x00j\x0f\x01\x00\x00j\x10\x01\x00\x00j\x11\x01\x00\x00j\x12\x01\x00\x00j\x13\x01\x00\x00j\x14\x01\x00\x00j\x15\x01\x00\x00j\x16\x01\x00\x00j\x17\x01\x00\x00j\x18\x01\x00\x00j\x19\x01\x00\x00j\x1a\x01\x00\x00j\x1b\x01\x00\x00j\x1c\x01\x00\x00j\x1d\x01\x00\x00j\x1e\x01\x00\x00j\x1f\x01\x00\x00j \x01\x00\x00j!\x01\x00\x00j"\x01\x00\x00j#\x01\x00\x00j$\x01\x00\x00j%\x01\x00\x00j&\x01\x00\x00j\'\x01\x00\x00j(\x01\x00\x00j)\x01\x00\x00j*\x01\x00\x00j+\x01\x00\x00j,\x01\x00\x00j-\x01\x00\x00j.\x01\x00\x00j/\x01\x00\x00j0\x01\x00\x00j1\x01\x00\x00j2\x01\x00\x00j3\x01\x00\x00j4\x01\x00\x00j5\x01\x00\x00j6\x01\x00\x00j7\x01\x00\x00j8\x01\x00\x00j9\x01\x00\x00j:\x01\x00\x00j;\x01\x00\x00j<\x01\x00\x00j=\x01\x00\x00j>\x01\x00\x00j?\x01\x00\x00j@\x01\x00\x00jA\x01\x00\x00jB\x01\x00\x00jC\x01\x00\x00jD\x01\x00\x00jE\x01\x00\x00jF\x01\x00\x00jG\x01\x00\x00jH\x01\x00\x00jI\x01\x00\x00jJ\x01\x00\x00jK\x01\x00\x00jL\x01\x00\x00jM\x01\x00\x00jN\x01\x00\x00jO\x01\x00\x00jP\x01\x00\x00jQ\x01\x00\x00jR\x01\x00\x00jS\x01\x00\x00jT\x01\x00\x00jU\x01\x00\x00jV\x01\x00\x00jW\x01\x00\x00jX\x01\x00\x00jY\x01\x00\x00jZ\x01\x00\x00j[\x01\x00\x00j\\\x01\x00\x00j]\x01\x00\x00j^\x01\x00\x00j_\x01\x00\x00j`\x01\x00\x00ja\x01\x00\x00jb\x01\x00\x00jc\x01\x00\x00jd\x01\x00\x00je\x01\x00\x00jf\x01\x00\x00jg\x01\x00\x00jh\x01\x00\x00ji\x01\x00\x00jj\x01\x00\x00jk\x01\x00\x00jl\x01\x00\x00jm\x01\x00\x00jn\x01\x00\x00jo\x01\x00\x00jp\x01\x00\x00jq\x01\x00\x00jr\x01\x00\x00js\x01\x00\x00jt\x01\x00\x00ju\x01\x00\x00jv\x01\x00\x00jw\x01\x00\x00jx\x01\x00\x00jy\x01\x00\x00jz\x01\x00\x00j{\x01\x00\x00j|\x01\x00\x00j}\x01\x00\x00j~\x01\x00\x00j\x7f\x01\x00\x00j\x80\x01\x00\x00j\x81\x01\x00\x00j\x82\x01\x00\x00j\x83\x01\x00\x00j\x84\x01\x00\x00j\x85\x01\x00\x00j\x86\x01\x00\x00j\x87\x01\x00\x00j\x88\x01\x00\x00j\x89\x01\x00\x00j\x8a\x01\x00\x00j\x8b\x01\x00\x00j\x8c\x01\x00\x00j\x8d\x01\x00\x00j\x8e\x01\x00\x00j\x8f\x01\x00\x00j\x90\x01\x00\x00j\x91\x01\x00\x00j\x92\x01\x00\x00j\x93\x01\x00\x00j\x94\x01\x00\x00j\x95\x01\x00\x00j\x96\x01\x00\x00j\x97\x01\x00\x00j\x98\x01\x00\x00j\x99\x01\x00\x00j\x9a\x01\x00\x00j\x9b\x01\x00\x00j\x9c\x01\x00\x00j\x9d\x01\x00\x00j\x9e\x01\x00\x00j\x9f\x01\x00\x00j\xa0\x01\x00\x00j\xa1\x01\x00\x00j\xa2\x01\x00\x00j\xa3\x01\x00\x00j\xa4\x01\x00\x00j\xa5\x01\x00\x00j\xa6\x01\x00\x00j\xa7\x01\x00\x00j\xa8\x01\x00\x00j\xa9\x01\x00\x00j\xaa\x01\x00\x00j\xab\x01\x00\x00j\xac\x01\x00\x00j\xad\x01\x00\x00j\xae\x01\x00\x00j\xaf\x01\x00\x00j\xb0\x01\x00\x00j\xb1\x01\x00\x00j\xb2\x01\x00\x00j\xb3\x01\x00\x00j\xb4\x01\x00\x00j\xb5\x01\x00\x00j\xb6\x01\x00\x00j\xb7\x01\x00\x00j\xb8\x01\x00\x00j\xb9\x01\x00\x00j\xba\x01\x00\x00j\xbb\x01\x00\x00j\xbc\x01\x00\x00j\xbd\x01\x00\x00j\xbe\x01\x00\x00j\xbf\x01\x00\x00j\xc0\x01\x00\x00j\xc1\x01\x00\x00j\xc2\x01\x00\x00j\xc3\x01\x00\x00j\xc4\x01\x00\x00j\xc5\x01\x00\x00j\xc6\x01\x00\x00j\xc7\x01\x00\x00j\xc8\x01\x00\x00j\xc9\x01\x00\x00j\xca\x01\x00\x00j\xcb\x01\x00\x00j\xcc\x01\x00\x00j\xcd\x01\x00\x00j\xce\x01\x00\x00j\xcf\x01\x00\x00j\xd0\x01\x00\x00j\xd1\x01\x00\x00j\xd2\x01\x00\x00j\xd3\x01\x00\x00j\xd4\x01\x00\x00j\xd5\x01\x00\x00j\xd6\x01\x00\x00j\xd7\x01\x00\x00j\xd8\x01\x00\x00j\xd9\x01\x00\x00j\xda\x01\x00\x00j\xdb\x01\x00\x00j\xdc\x01\x00\x00j\xdd\x01\x00\x00j\xde\x01\x00\x00j\xdf\x01\x00\x00j\xe0\x01\x00\x00j\xe1\x01\x00\x00j\xe2\x01\x00\x00j\xe3\x01\x00\x00j\xe4\x01\x00\x00j\xe5\x01\x00\x00j\xe6\x01\x00\x00j\xe7\x01\x00\x00j\xe8\x01\x00\x00j\xe9\x01\x00\x00j\xea\x01\x00\x00j\xeb\x01\x00\x00j\xec\x01\x00\x00j\xed\x01\x00\x00j\xee\x01\x00\x00j\xef\x01\x00\x00j\xf0\x01\x00\x00j\xf1\x01\x00\x00j\xf2\x01\x00\x00j\xf3\x01\x00\x00j\xf4\x01\x00\x00j\xf5\x01\x00\x00j\xf6\x01\x00\x00j\xf7\x01\x00\x00j\xf8\x01\x00\x00j\xf9\x01\x00\x00j\xfa\x01\x00\x00j\xfb\x01\x00\x00j\xfc\x01\x00\x00j\xfd\x01\x00\x00j\xfe\x01\x00\x00j\xff\x01\x00\x00j\x00\x02\x00\x00j\x01\x02\x00\x00j\x02\x02\x00\x00j\x03\x02\x00\x00j\x04\x02\x00\x00j\x05\x02\x00\x00j\x06\x02\x00\x00j\x07\x02\x00\x00j\x08\x02\x00\x00j\t\x02\x00\x00j\n\x02\x00\x00j\x0b\x02\x00\x00j\x0c\x02\x00\x00j\r\x02\x00\x00j\x0e\x02\x00\x00j\x0f\x02\x00\x00j\x10\x02\x00\x00j\x11\x02\x00\x00j\x12\x02\x00\x00j\x13\x02\x00\x00j\x14\x02\x00\x00j\x15\x02\x00\x00j\x16\x02\x00\x00j\x17\x02\x00\x00j\x18\x02\x00\x00j\x19\x02\x00\x00j\x1a\x02\x00\x00j\x1b\x02\x00\x00j\x1c\x02\x00\x00j\x1d\x02\x00\x00j\x1e\x02\x00\x00j\x1f\x02\x00\x00j \x02\x00\x00j!\x02\x00\x00j"\x02\x00\x00j#\x02\x00\x00j$\x02\x00\x00j%\x02\x00\x00j&\x02\x00\x00j\'\x02\x00\x00j(\x02\x00\x00j)\x02\x00\x00j*\x02\x00\x00j+\x02\x00\x00j,\x02\x00\x00j-\x02\x00\x00j.\x02\x00\x00j/\x02\x00\x00j0\x02\x00\x00j1\x02\x00\x00j2\x02\x00\x00j3\x02\x00\x00j4\x02\x00\x00j5\x02\x00\x00j6\x02\x00\x00j7\x02\x00\x00j8\x02\x00\x00j9\x02\x00\x00j:\x02\x00\x00j;\x02\x00\x00j<\x02\x00\x00j=\x02\x00\x00j>\x02\x00\x00j?\x02\x00\x00j@\x02\x00\x00jA\x02\x00\x00jB\x02\x00\x00jC\x02\x00\x00jD\x02\x00\x00jE\x02\x00\x00jF\x02\x00\x00jG\x02\x00\x00jH\x02\x00\x00jI\x02\x00\x00jJ\x02\x00\x00jK\x02\x00\x00jL\x02\x00\x00jM\x02\x00\x00jN\x02\x00\x00jO\x02\x00\x00jP\x02\x00\x00jQ\x02\x00\x00jR\x02\x00\x00jS\x02\x00\x00jT\x02\x00\x00jU\x02\x00\x00jV\x02\x00\x00jW\x02\x00\x00jX\x02\x00\x00jY\x02\x00\x00jZ\x02\x00\x00j[\x02\x00\x00j\\\x02\x00\x00j]\x02\x00\x00j^\x02\x00\x00j_\x02\x00\x00j`\x02\x00\x00ja\x02\x00\x00jb\x02\x00\x00jc\x02\x00\x00jd\x02\x00\x00je\x02\x00\x00jf\x02\x00\x00jg\x02\x00\x00e}\x94(ji\x02\x00\x00}\x94jq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8ce/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/available_dst.png\x94\x8cm/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_concordance.png\x94\x8cl/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/illumina_concordance.png\x94\x8cm/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_concordance.csv\x94\x8cl/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/illumina_concordance.csv\x94\x8cj/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_coverage.png\x94e}\x94(ji\x02\x00\x00}\x94(\x8c\x08dst_data\x94K\x00N\x86\x94\x8c\x16pheno_concordance_plot\x94K\x01N\x86\x94\x8c\x15geno_concordance_plot\x94K\x02N\x86\x94\x8c\x15pheno_concordance_csv\x94K\x03N\x86\x94\x8c\x18illumina_concordance_csv\x94K\x04N\x86\x94\x8c\x13pheno_coverage_plot\x94K\x05N\x86\x94ujq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bj\x9d\x02\x00\x00j\x95\x02\x00\x00j\x9f\x02\x00\x00j\x96\x02\x00\x00j\xa1\x02\x00\x00j\x97\x02\x00\x00j\xa3\x02\x00\x00j\x98\x02\x00\x00j\xa5\x02\x00\x00j\x99\x02\x00\x00j\xa7\x02\x00\x00j\x9a\x02\x00\x00ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(\x8f\x94(\x8c\x0cpyrazinamide\x94\x8c\x0cmoxifloxacin\x94\x90\x89\x88\x89e}\x94(ji\x02\x00\x00}\x94(\x8c\x0cignore_drugs\x94K\x00N\x86\x94\x8c\x14unknown_is_resistant\x94K\x01N\x86\x94\x8c\x14minor_is_susceptible\x94K\x02N\x86\x94\x8c\x13failed_is_resistant\x94K\x03N\x86\x94ujq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bj\xbb\x02\x00\x00j\xb6\x02\x00\x00j\xbd\x02\x00\x00\x89j\xbf\x02\x00\x00\x88j\xc1\x02\x00\x00\x89ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(ji\x02\x00\x00}\x94jq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\xe8\x03M\xe8\x03\x8c&/hps/scratch/lsf_tmpdir/hl-codon-09-04\x94e}\x94(ji\x02\x00\x00}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94\x8c\x07disk_mb\x94K\x03N\x86\x94\x8c\x06tmpdir\x94K\x04N\x86\x94ujq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bj\xe3\x02\x00\x00K\x01j\xe5\x02\x00\x00K\x01j\xe7\x02\x00\x00M\xe8\x03j\xe9\x02\x00\x00M\xe8\x03j\xeb\x02\x00\x00j\xe0\x02\x00\x00ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cl/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/analysis.processed.ipynb\x94a}\x94(ji\x02\x00\x00}\x94\x8c\x08notebook\x94K\x00N\x86\x94sjq\x02\x00\x00]\x94(js\x02\x00\x00jt\x02\x00\x00ejs\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00js\x02\x00\x00sNt\x94bjt\x02\x00\x00jw\x02\x00\x00jy\x02\x00\x00\x85\x94R\x94(jy\x02\x00\x00)}\x94j}\x02\x00\x00jt\x02\x00\x00sNt\x94bj\xfd\x02\x00\x00j\xfa\x02\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x0bsamplesheet\x94\x8c\x1a../../docs/samplesheet.csv\x94\x8c\nphenosheet\x94\x8c\x19../../docs/phenotypes.csv\x94\x8c\x11mykrobe_panel_url\x94\x8c/https://ndownloader.figshare.com/files/14120198\x94\x8c\tmatch_len\x94K\x05\x8c\x07padding\x94Kd\x8c\x07filters\x94}\x94(\x8c\x08min_covg\x94K\x03\x8c\x0fmin_strand_bias\x94G?\x84z\xe1G\xae\x14{\x8c\x07min_frs\x94G?\xe6ffffff\x8c\tmax_indel\x94K\x14\x8c\x0bmin_gt_conf\x94}\x94(\x8c\x08nanopore\x94K\x05\x8c\x08illumina\x94K\x05uu\x8c\ncontainers\x94}\x94(\x8c\x04base\x94\x8c\x11docker://bash:5.1\x94\x8c\x07mykrobe\x94\x8c=docker://quay.io/biocontainers/mykrobe:0.10.0--py38h8e3bb3f_0\x94\x8c\x05conda\x94\x8c%docker://continuumio/miniconda3:4.9.2\x94\x8c\x05drprg\x94\x8c\'docker://quay.io/mbhall88/drprg:cb4f9b8\x94\x8c\x05mafft\x94\x8c6docker://quay.io/biocontainers/mafft:7.475--h516909a_0\x94\x8c\x05happy\x94\x8c<docker://quay.io/biocontainers/hap.py:0.3.14--py27h5c5a3ab_0\x94\x8c\x08bcftools\x94\x8c8docker://quay.io/biocontainers/bcftools:1.11--h7c999a4_0\x94uu\x8c\x04rule\x94\x8c\x0fanalyse_results\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cV/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/workflow/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction');
######## snakemake preamble end #########

# %% [markdown]
# # Evaluation of Nanopore-base drug resistance prediction
#
# This notebook contains the figures and tables for the drug resistance prediction component of our paper *Nanopore sequencing for _Mycobacterium tuberculosis_ public health applications*

# %%
import pandas as pd
from pathlib import Path
from typing import Tuple
from itertools import product
from collections import defaultdict
import pandas as pd
import numpy as np
from scipy import stats
from math import sqrt
from enum import Enum
from dataclasses import dataclass
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import seaborn as sns
import upsetplot

phenosheet = snakemake.input.phenosheet
plt.style.use("ggplot")
CONF = snakemake.params.get("confidence", 0.95)

# %% [markdown]
# Load the concordance data. This gives us the mykrobe Illumina and Nanopore calls for each sample-drug combination.

# %%
covdf = pd.read_csv(snakemake.input.coverage, index_col="sample")
# covdf = pd.read_csv("../../coverage.csv", index_col="sample")

# %%
concordance_files = [Path(p) for p in snakemake.input.concordance]
# concordance_files = [Path(p) for p in Path("../../results/concordance/").rglob("*.csv")]

# %%
frames = []
for p in concordance_files:
    sample, tool = p.name.split(".")[0:2]
    tech = p.parts[-3]
    site = p.parts[-2]
    table = pd.read_csv(p)
    table["sample"] = sample
    table["tool"] = tool
    table["tech"] = tech
    table["site"] = site
    frames.append(table)

# %%
calls = pd.concat(frames)
calls.reset_index(drop=True, inplace=True)
valid_samples = set(calls["sample"])

# %%
calls
# Out:
#                drug classification true_call test_call     sample     tool  \
# 0         Ofloxacin             TN         S         S   mada_1-7  mykrobe
# 1      Moxifloxacin             TN         S         S   mada_1-7  mykrobe
# 2         Isoniazid             TP         R         R   mada_1-7  mykrobe
# 3         Kanamycin             TN         S         S   mada_1-7  mykrobe
# 4        Ethambutol             TN         S         S   mada_1-7  mykrobe
# ...             ...            ...       ...       ...        ...      ...
# 6639  Ciprofloxacin             TN         S         U  18_620606    drprg
# 6640   Pyrazinamide             FP         S         R  18_620606    drprg
# 6641     Rifampicin             TN         S         U  18_620606    drprg
# 6642       Amikacin             TN         S         S  18_620606    drprg
# 6643    Capreomycin             TN         S         S  18_620606    drprg
#
#           tech        site
# 0     illumina  madagascar
# ...

# %% [markdown]
# Load the phenotype information

# %%
pheno = pd.read_csv(phenosheet).melt(
    id_vars=["sample"], var_name="drug", value_name="phenotype"
)
arr = []
for r in pheno["phenotype"]:
    if pd.isna(r):
        arr.append(r)
    elif r.upper() in ("R", "S"):
        arr.append(r.upper())
    else:
        arr.append(None)
pheno["phenotype"] = arr
pheno = pheno.loc[pheno["sample"].isin(valid_samples)]
pheno.set_index(["sample", "drug"], drop=False, inplace=True)
pheno.sort_index(inplace=True)

# %%
pheno
# Out:
#                                 sample               drug phenotype
# sample    drug
# R15311    amikacin              R15311           amikacin         S
#           amikacin-lpa          R15311       amikacin-lpa       NaN
#           capreomycin           R15311        capreomycin       NaN
#           capreomycin-lpa       R15311    capreomycin-lpa       NaN
#           ciprofloxacin-lpa     R15311  ciprofloxacin-lpa       NaN
# ...                                ...                ...       ...
# mada_2-53 pyrazinamide       mada_2-53       pyrazinamide       NaN
#           rifampicin         mada_2-53         rifampicin         R
#           rifampicin-lpa     mada_2-53     rifampicin-lpa         S
#           streptomycin       mada_2-53       streptomycin         S
#           thioacetazone      mada_2-53      thioacetazone         R
#
# [2882 rows x 3 columns]

# %%
DRUGS = sorted(set(calls["drug"]))

# %%
d = {}
for drug in map(str.lower, DRUGS):
    if drug in snakemake.params.ignore_drugs:
        continue
    samples = list(pheno.query("drug == @drug").dropna()["sample"])
    if samples:
        d[drug.upper()] = samples
#     lpa = drug + "-lpa"
#     d[lpa.upper()] = list(pheno.query("drug == @lpa").dropna()["sample"])

# %%
upset_data = upsetplot.from_contents(d)

# %% [markdown]
# ## Figure 1
# Culture-based drug susceptibility data available for samples. Each row is a drug, and the columns represent a set of samples that have phenotype information for those drugs with a filled cell. The top panel shows the number of samples in the set for that combination of drugs. The bar plot in the left panel shows the number of samples with phenotype information for that drug.

# %%
tbl = pd.DataFrame([(f"{k.split('-')[0].capitalize()}{''.join(map(str.upper, k.partition('-')[-2:]))}", len(v)) for k, v in sorted(d.items())], columns=["Drug", "Count"])
print(tbl.to_latex(index=False))
# Out:
# \begin{tabular}{lr}
# \toprule
#         Drug &  Count \\
# \midrule
#     Amikacin &     89 \\
#  Capreomycin &     52 \\
#   Ethambutol &     91 \\
#    Isoniazid &     99 \\
#    Kanamycin &     52 \\
#    Ofloxacin &     87 \\
#   Rifampicin &     92 \\
# Streptomycin &     91 \\
# \bottomrule
# \end{tabular}

# %%
fig, ax = plt.subplots()
p = upsetplot.plot(
    upset_data,
    fig=fig,
    sort_by="cardinality",
    orientation="horizontal",
    show_counts=True,
)
p["totals"].set_xticks([0, 50, 100])
p["intersections"].set_ylabel("count")
ax.axis("off")
# fig.set_figwidth(8)
# fig.set_figheight(10)
fig.set_dpi(300)

# %%
fig.savefig(snakemake.output.dst_data)

# %% [markdown]
# ## Resistance prediction performance of mykrobe
# mykrobe has been rigorously evaluated on datasets which much better/broader phenotype availability. However, it's prediction ability on ONT data has only been validated with 5 samples. We look to validate it's performance on this dataset's Illumina and ONT data, for those drugs/samples where phenotype data is available.
# We will also discuss the causes for any discrepencies and look to COMPASS/bcftools calls for adjudication if possible.
#
# The figure for this section will basically be a copy of [5c/d from the mykrobe nature comms paper](https://www.nature.com/articles/ncomms10063#Fig5) (side-by-side bar charts showing resistant/susceptible samples, with stacked bars indicating FPs and FNs)

# %%
# taken from https://apps.who.int/iris/bitstream/handle/10665/130918/9789241548809_eng.pdf?sequence=1&isAllowed=y
drug_abbrev = {
    "ethambutol": "E",
    "isoniazid": "H",
    "pyrazinamide": "Z",
    "rifampicin": "R",
    "streptomycin": "S",
    "kanamycin": "Km",
    "amikacin": "Am",
    "ofloxacin": "Ofx",
    "capreomycin": "Cm",
    "moxifloxacin": "Mfx",
    "ciprofloxacin": "Cfx",
}
ignore_drugs = snakemake.params.get("ignore_drugs", set())


class Prediction(Enum):
    Resistant = "R"
    Susceptible = "S"
    MinorResistance = "r"
    Unknown = "U"
    Failed = "F"

    def __str__(self) -> str:
        return self.value


class Classification(Enum):
    TruePositive = "TP"
    FalsePositive = "FP"
    TrueNegative = "TN"
    FalseNegative = "FN"

    def __str__(self) -> str:
        return self.value


class Classifier:
    def __init__(
        self,
        minor_is_susceptible: bool = False,
        unknown_is_resistant: bool = False,
        failed_is_resistant: bool = False,
    ):
        self.minor_is_susceptible = minor_is_susceptible
        self.unknown_is_resistant = unknown_is_resistant
        self.failed_is_resistant = failed_is_resistant
        self.susceptible = {Prediction.Susceptible}
        self.resistant = {Prediction.Resistant}
        if self.minor_is_susceptible:
            self.susceptible.add(Prediction.MinorResistance)
        else:
            self.resistant.add(Prediction.MinorResistance)

        if self.unknown_is_resistant:
            self.resistant.add(Prediction.Unknown)
        else:
            self.susceptible.add(Prediction.Unknown)

        if self.failed_is_resistant:
            self.resistant.add(Prediction.Failed)
        else:
            self.susceptible.add(Prediction.Failed)

    def from_predictions(
        self, y_true: Prediction, y_pred: Prediction
    ) -> Classification:
        if y_true in self.susceptible:
            expected_susceptible = True
        elif y_true in self.resistant:
            expected_susceptible = False
        else:
            raise NotImplementedError(f"Don't know how to classify {y_true} calls yet")

        if y_pred in self.susceptible:
            called_susceptible = True
        elif y_pred in self.resistant:
            called_susceptible = False
        else:
            raise NotImplementedError(f"Don't know how to classify {y_pred} calls yet")

        if expected_susceptible and called_susceptible:
            return Classification.TrueNegative
        elif expected_susceptible and not called_susceptible:
            return Classification.FalsePositive
        elif not expected_susceptible and not called_susceptible:
            return Classification.TruePositive
        else:
            return Classification.FalseNegative



@dataclass
class ConfusionMatrix:
    tp: int = 0
    tn: int = 0
    fp: int = 0
    fn: int = 0

    def ravel(self) -> Tuple[int, int, int, int]:
        """Return the matrix as a flattened tuple.
        The order of return is TN, FP, FN, TP
        """
        return self.tn, self.fp, self.fn, self.tp

    def as_matrix(self) -> np.ndarray:
        """Returns a 2x2 matrix [[TN, FP], [FN, TP]]"""
        return np.array([[self.tn, self.fp], [self.fn, self.tp]])

    def num_positive(self) -> int:
        """Number of TPs and FNs - i.e. actual condition positive"""
        return self.tp + self.fn

    def num_negative(self) -> int:
        """Number of TNs and FPs - i.e. actual condition negative"""
        return self.tn + self.fp

    def ppv(self) -> Tuple[float, float, float]:
        """Also known as precision"""
        try:
            ppv = self.tp / (self.tp + self.fp)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tp, n_f=self.fp)
            return ppv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def npv(self) -> Tuple[float, float, float]:
        """Negative predictive value"""
        try:
            npv = self.tn / (self.tn + self.fn)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tn, n_f=self.fn)
            return npv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def sensitivity(self) -> float:
        """Also known as recall and true positive rate (TPR)"""
        try:
            return self.tp / self.num_positive()
        except ZeroDivisionError:
            return None

    def specificity(self) -> float:
        """Also known as selectivity and true negative rate (TNR)"""
        try:
            return self.tn / self.num_negative()
        except ZeroDivisionError:
            return None

    def fnr(self) -> Tuple[float, float, float]:
        """False negative rate or VME (very major error rate)"""
        try:
            fnr = self.fn / self.num_positive()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fn, n_f=self.tp)
            return fnr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def fpr(self) -> Tuple[float, float, float]:
        """False positive rate or ME (major error rate)"""
        try:
            fpr = self.fp / self.num_negative()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fp, n_f=self.tn)
            return fpr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def f_score(self, beta: float = 1.0) -> float:
        """Harmonic mean of precision and recall.
        When beta is set to 0, you get precision. When beta is set to 1, you get the
        unweighted F-score which is the harmonic mean of precision and recall. Setting
        beta to 2 weighs recall twice as much as precision. Setting beta to 0.5 weighs
        precision twice as much as recall.
        """
        ppv = self.precision()
        tpr = self.recall()
        if ppv is None or tpr is None:
            return None
        beta2 = beta ** 2

        return ((beta2 + 1) * ppv * tpr) / ((beta2 * ppv) + tpr)

    @staticmethod
    def from_series(s: pd.Series) -> "ConfusionMatrix":
        tp = s.get("TP", 0)
        fp = s.get("FP", 0)
        fn = s.get("FN", 0)
        tn = s.get("TN", 0)
        return ConfusionMatrix(tp=tp, fn=fn, fp=fp, tn=tn)


def confidence_interval(n_s: int, n_f: int, conf: float = CONF) -> Tuple[float, float]:
    """Calculate the Wilson score interval.
    Equation take from https://en.wikipedia.org/wiki/Binomial_proportion_confidence_interval#Wilson_score_interval
    n_s: Number of successes or, in the case of confusion matrix statistics, the numerator
    n_f: Number of failures or, in the case of confusion matrix statistics, the denominator minus the numerator
    conf: the confidence level. i.e. 0.95 is 95% confidence
    """
    n = n_f + n_s
    z = stats.norm.ppf(1 - (1 - conf) / 2)  # two-sided
    z2 = z ** 2
    nz2 = n + z2
    A = (n_s + (0.5 * z2)) / nz2
    B = z / nz2
    C = sqrt(((n_s * n_f) / n) + (z2 / 4))
    CI = B * C
    return A - CI, A + CI


def round_up_to_base(x, base=10):
    return int(x + (base - x) % base)


def round_down_to_base(x, base=10):
    return int(x - (x % base))

# %%
pheno_clf = []
minor_is_susceptible = snakemake.params.get("minor_is_susceptible", False)
unknown_is_resistant = snakemake.params.get("unknown_is_resistant", False)
failed_is_resistant = snakemake.params.get("failed_is_resistant", False)
classifier = Classifier(
    unknown_is_resistant=unknown_is_resistant, 
    minor_is_susceptible=minor_is_susceptible,
    failed_is_resistant=failed_is_resistant
)

for ix, row in calls.iterrows():
    drug = row["drug"].lower()
    if drug in ignore_drugs:
        continue

    sample = row["sample"]
    try:
        ph = pheno.loc[(sample, drug), "phenotype"]
        if pd.isna(ph).all():
            continue
        else:
            truth = Prediction(ph[0])
    except KeyError:
        continue
    
    tech = row["tech"]
    if tech == "illumina":
        covg = covdf.loc[sample]["illumina_covg"]
    else:
        covg = covdf.loc[sample]["nanopore_covg"]
    
    pred = Prediction(row["test_call"])    
    clf = classifier.from_predictions(truth, pred)

    pheno_clf.append((sample, drug, str(clf), tech, covg, row["tool"], row["site"]))

# %%
clf_df = pd.DataFrame(
    pheno_clf, columns=["sample", "drug", "classification", "technology", "coverage", "tool", "site"]
)

# %%
pheno_cms = defaultdict()
TOOLS = ["drprg", "mykrobe"]
TECHS = ["nanopore", "illumina"]
PHENO_DRUGS = set()

for drug, tech, tool in product(set(clf_df["drug"]), TECHS, TOOLS):
    s = clf_df.query("drug == @drug and technology == @tech and tool == @tool").value_counts(
        subset=["classification"]
    )
    cm = ConfusionMatrix.from_series(s)
    pheno_cms[(drug, tech, tool)] = cm
    PHENO_DRUGS.add(drug)
    
PHENO_DRUGS = sorted(PHENO_DRUGS)

# %%
metrics = []
for (drug, tech, tool), cm in pheno_cms.items():
        #         sensitivity = cm.sensitivity()
        #         specificity = cm.specificity()
    ppv = cm.ppv()[0]
    npv = cm.npv()[0]
    vme = cm.fnr()[0]
    me = cm.fpr()[0]
    metrics.append((drug, tech, tool, ppv, npv, vme, me))

summary_cols = [
    "drug",
    "tech",
    "tool",
    "PPV",
    "NPV",
    "FNR",
    "FPR",
]

summary = pd.DataFrame(
    metrics,
    columns=summary_cols,
).melt(id_vars=["drug", "tech", "tool"], var_name="metric")

# %% [markdown]
# ## Figure 2
# Number of resistant (left) and susceptible (right) phenotypes correctly identified by mykrobe from Illumina (blue) and Nanopore (purple) data from the same samples. The red bars indicate missed (FN) or incorrect (FP) predictions. The x-axis shows the drugs with available phenotype data that mykrobe also makes predictions for. E - ethambutol; H - isoniazid; Z - pyrazinamide; R - rifampicin; S - streptomycin; Km - kanamycin; Am - amikacin; Ofx - ofloxacin; Cm - capreomycin; Mfx - moxifloxacin.

# %%
ggplot_cm = plt.rcParams["axes.prop_cycle"].by_key()["color"]
red = ggplot_cm[0]
blue = ggplot_cm[1]
black = ggplot_cm[3]
edgecol = "black"
cmap = {}
i = 0
for tool in TOOLS:
    c = ggplot_cm[i]
    if c in (red, black):
        i += 1
        c = ggplot_cm[i]
    cmap[tool] = c
    i += 1

fig, axes = plt.subplots(ncols=2, figsize=(13, 8), dpi=300, sharey=True)
axR = axes.flatten()[0]
axS = axes.flatten()[1]

# plot details
bar_width = 0.15
epsilon = 0.05
line_width = 0.5
alpha = 1.0
hatch = "////"

all_positions = []
for i, (tech, tool) in enumerate(product(TECHS, TOOLS)):
    tps = [pheno_cms[(d, tech, tool)].tp for d in PHENO_DRUGS]
    fps = [pheno_cms[(d, tech, tool)].fp for d in PHENO_DRUGS]
    tns = [pheno_cms[(d, tech, tool)].tn for d in PHENO_DRUGS]
    fns = [pheno_cms[(d, tech, tool)].fn for d in PHENO_DRUGS]
    
    positions = [p + ((bar_width + epsilon) * i) for p in np.arange(len(tps))]
    all_positions.append(positions)
    
    colour = cmap[tool]

    # resistance bar plots
    tps_bar = axR.bar(
        positions,
        tps,
        bar_width,
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    fns_bar = axR.bar(
        positions,
        fns,
        bar_width,
        bottom=tps,
        color=red,
        edgecolor=edgecol,
        linewidth=line_width,
    )

    # susceptible bar plots
    tns_bar = axS.bar(
        positions,
        tns,
        bar_width,
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    fps_bar = axS.bar(
        positions,
        fps,
        bar_width,
        bottom=tns,
        color=red,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    
    if tech == "nanopore":
        for bar in tps_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in fps_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in fns_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in tns_bar.patches:
            bar.set_hatch(hatch)
    else:
        tps_bar.set_label(tool)

fps_bar.set_label("FP")
fns_bar.set_label("FN")
labels = [drug_abbrev[d] for d in PHENO_DRUGS]
label_pos = [np.mean(ps) for ps in zip(*all_positions)]
plt.xticks(label_pos, labels, rotation=90)
axR.set_ylabel("samples")
axR.set_xticks(label_pos)
axR.set_xticklabels(axS.get_xticklabels(), rotation=90)
axR.set_title("Resistant")
axS.set_title("Susceptible")

axS.legend(loc="best", prop={"size": 11})
leghandles, leglabels = axR.get_legend_handles_labels()
from matplotlib.patches import Patch
hatch_leghandle = Patch(facecolor='white', hatch=hatch)
leghandles.insert(2, hatch_leghandle)
leglabels.insert(2, "Nanopore")
axR.legend(leghandles, leglabels, loc="best", prop={"size": 11})
sns.despine()
plt.tight_layout()

# %%
fig.savefig(snakemake.output.pheno_concordance_plot)

# %%
counts = clf_df.groupby(["drug", "tool", "technology", "classification"])["sample"].count()
table = summary.set_index(["drug", "tech", "tool", "metric"])["value"].unstack().reset_index()

for clf in ["TP", "FP", "FN", "TN"]:
    table[clf] = 0

for i, row in table.iterrows():
    ix = (row["drug"], row["tech"], row["tool"])
    cm = pheno_cms[ix]
    table.at[i, "TP"] = cm.tp
    table.at[i, "FP"] = cm.fp
    table.at[i, "TN"] = cm.tn
    table.at[i, "FN"] = cm.fn
    
for k in ["drug", "tech", "tool"]:
    table[k] = table[k].str.capitalize()

table.fillna("-", inplace=True)
summary_cols = ["drug", "tech", "tool", "PPV", "NPV", "FNR", "FPR", "TP", "TN", "FN", "FP"]
table = table[summary_cols]
table.rename(columns={"tech": "technology"}, inplace=True)

# %% [markdown]
# This table summarises the results visualised above in Figure 2

# %%
rows = []
ci_str = (
    lambda tup: f"{tup[0]:.1%} ({tup[1]*100:.1f}-{tup[2]:.1%})"
    if tup[0] is not None
    else "-"
)
for i, row in table.iterrows():
    cm = ConfusionMatrix(tp=row["TP"], fp=row["FP"], tn=row["TN"], fn=row["FN"])
    npv = cm.npv()
    ppv = cm.ppv()
    vme = cm.fnr()
    me = cm.fpr()
    fn_str = f"{cm.fn}({cm.num_positive()})"
    fp_str = f"{cm.fp}({cm.num_negative()})"
    rows.append(
        (
            row["drug"].capitalize(),
            row["technology"],
            row["tool"],
            fn_str,
            fp_str,
            ci_str(vme),
            ci_str(me),
            ci_str(ppv),
            ci_str(npv),
        )
    )
pretty_cols = [
    "Drug",
    "Technology",
    "Tool",
    "FN(R)",
    "FP(S)",
    "FNR(95% CI)",
    "FPR(95% CI)",
    "PPV(95% CI)",
    "NPV(95% CI)",
]
table = pd.DataFrame(rows, columns=pretty_cols)
table
# Out:
#             Drug Technology     Tool   FN(R)   FP(S)           FNR(95% CI)  \
# 0       Amikacin   Illumina    Drprg   0(11)   2(78)      0.0% (0.0-25.9%)
# 1       Amikacin   Illumina  Mykrobe   1(11)   2(78)      9.1% (1.6-37.7%)
# 2       Amikacin   Nanopore    Drprg   0(11)   2(78)      0.0% (0.0-25.9%)
# 3       Amikacin   Nanopore  Mykrobe   0(11)   2(78)      0.0% (0.0-25.9%)
# 4    Capreomycin   Illumina    Drprg    1(1)   1(51)  100.0% (20.7-100.0%)
# 5    Capreomycin   Illumina  Mykrobe    1(1)   1(51)  100.0% (20.7-100.0%)
# 6    Capreomycin   Nanopore    Drprg    1(1)   1(51)  100.0% (20.7-100.0%)
# 7    Capreomycin   Nanopore  Mykrobe    1(1)   1(51)  100.0% (20.7-100.0%)
# 8     Ethambutol   Illumina    Drprg   4(14)  14(77)    28.6% (11.7-54.6%)
# 9     Ethambutol   Illumina  Mykrobe   4(14)  14(77)    28.6% (11.7-54.6%)
# 10    Ethambutol   Nanopore    Drprg   4(14)  14(77)    28.6% (11.7-54.6%)
# ...

# %% [markdown]
# ## Table 1 Comparison of drug resistance predictions with culture-based phenotype
#
# For this comparison, we assume the drug susceptibility testing phenotype is correct and evaluate mykrobe Illumina and Nanopore resistance predictions accordingly. Pyrazinamide and Moxifloxacin are excluded as phenotype information is only available for 1 sample.
#
# FN=false negative; R=number of resistant samples; FP=false positive; S=number of susceptible samples; FNR=false negative rate; FPR=false positive rate; PPV=positive predictive value; NPV=negative predictive value; CI=Wilson score confidence interval

# %%
print(table.to_markdown(index=False))
# Out:
# | Drug         | Technology   | Tool    | FN(R)   | FP(S)   | FNR(95% CI)          | FPR(95% CI)        | PPV(95% CI)        | NPV(95% CI)          |
# |:-------------|:-------------|:--------|:--------|:--------|:---------------------|:-------------------|:-------------------|:---------------------|
# | Amikacin     | Illumina     | Drprg   | 0(11)   | 2(78)   | 0.0% (0.0-25.9%)     | 2.6% (0.7-8.9%)    | 84.6% (57.8-95.7%) | 100.0% (95.2-100.0%) |
# | Amikacin     | Illumina     | Mykrobe | 1(11)   | 2(78)   | 9.1% (1.6-37.7%)     | 2.6% (0.7-8.9%)    | 83.3% (55.2-95.3%) | 98.7% (93.0-99.8%)   |
# | Amikacin     | Nanopore     | Drprg   | 0(11)   | 2(78)   | 0.0% (0.0-25.9%)     | 2.6% (0.7-8.9%)    | 84.6% (57.8-95.7%) | 100.0% (95.2-100.0%) |
# | Amikacin     | Nanopore     | Mykrobe | 0(11)   | 2(78)   | 0.0% (0.0-25.9%)     | 2.6% (0.7-8.9%)    | 84.6% (57.8-95.7%) | 100.0% (95.2-100.0%) |
# ...

# %%
print(table.to_latex(index=False))
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#         Drug & Technology &    Tool &  FN(R) &  FP(S) &          FNR(95\% CI) &        FPR(95\% CI) &        PPV(95\% CI) &          NPV(95\% CI) \\
# \midrule
#     Amikacin &   Illumina &   Drprg &  0(11) &  2(78) &     0.0\% (0.0-25.9\%) &    2.6\% (0.7-8.9\%) & 84.6\% (57.8-95.7\%) & 100.0\% (95.2-100.0\%) \\
#     Amikacin &   Illumina & Mykrobe &  1(11) &  2(78) &     9.1\% (1.6-37.7\%) &    2.6\% (0.7-8.9\%) & 83.3\% (55.2-95.3\%) &   98.7\% (93.0-99.8\%) \\
#     Amikacin &   Nanopore &   Drprg &  0(11) &  2(78) &     0.0\% (0.0-25.9\%) &    2.6\% (0.7-8.9\%) & 84.6\% (57.8-95.7\%) & 100.0\% (95.2-100.0\%) \\
#     Amikacin &   Nanopore & Mykrobe &  0(11) &  2(78) &     0.0\% (0.0-25.9\%) &    2.6\% (0.7-8.9\%) & 84.6\% (57.8-95.7\%) & 100.0\% (95.2-100.0\%) \\
#  Capreomycin &   Illumina &   Drprg &   1(1) &  1(51) & 100.0\% (20.7-100.0\%) &   2.0\% (0.3-10.3\%) &   0.0\% (0.0-79.3\%) &   98.0\% (89.7-99.7\%) \\
# ...

# %%
table.to_csv(snakemake.output.pheno_concordance_csv, na_rep="-", index=False)

# %%
clf_df
# Out:
#         sample          drug classification technology  coverage     tool  \
# 0     mada_1-7     ofloxacin             TN   illumina     60.00  mykrobe
# 1     mada_1-7     isoniazid             TP   illumina     60.00  mykrobe
# 2     mada_1-7     kanamycin             TN   illumina     60.00  mykrobe
# 3     mada_1-7    ethambutol             FN   illumina     60.00  mykrobe
# 4     mada_1-7  streptomycin             FP   illumina     60.00  mykrobe
# ...        ...           ...            ...        ...       ...      ...
# 2607    R26778      amikacin             TP   illumina     60.00    drprg
# 2608    R26778     ofloxacin             TN   nanopore     84.43  mykrobe
# 2609    R26778      amikacin             TP   nanopore     84.43  mykrobe
# 2610    R26778     ofloxacin             TN   nanopore     84.43    drprg
# 2611    R26778      amikacin             TP   nanopore     84.43    drprg
#
#               site
# 0       madagascar
# 1       madagascar
# ...

# %%
data = []

step = 10
tech = "nanopore"
start = round_down_to_base(
    clf_df.query("technology==@tech")["coverage"].min(), base=step
)
stop = (
    round_up_to_base(clf_df.query("technology==@tech")["coverage"].max(), base=step)
    + step
)
coverages = np.arange(start=start, stop=stop, step=step)
for i, covg in enumerate(coverages[:-1]):
    next_cov = coverages[i + 1]
    subdf = clf_df.query(
        "coverage > @covg and coverage <= @next_cov and technology == @tech"
    )
    n_samples = len(set(subdf['sample']))
    for tool in TOOLS:
        s = subdf.query("tool == @tool").value_counts(subset="classification")
        cm = ConfusionMatrix.from_series(s)
        total = sum(cm.ravel())
        
        data.append((covg, "FP", cm.fp / total, tech, n_samples, tool))
        data.append((covg, "TP", cm.tp / total, tech, n_samples, tool))
        data.append((covg, "FN", cm.fn / total, tech, n_samples, tool))
        data.append((covg, "TN", cm.tn / total, tech, n_samples, tool))


tech = "illumina"
start = round_down_to_base(
    clf_df.query("technology==@tech")["coverage"].min(), base=step
)
stop = round_up_to_base(clf_df.query("technology==@tech")["coverage"].max(), base=step)
coverages = np.arange(start=start, stop=stop, step=step)
for i, covg in enumerate(coverages[:-1]):
    next_cov = coverages[i + 1]
    subdf = clf_df.query(
        "coverage > @covg and coverage <= @next_cov and technology == @tech"
    )
    n_samples = len(set(subdf['sample']))
    for tool in TOOLS:
        s = subdf.query("tool == @tool").value_counts(subset="classification")
        cm = ConfusionMatrix.from_series(s)
        total = sum(cm.ravel())
        
        data.append((covg, "FP", cm.fp / total, tech, n_samples, tool))
        data.append((covg, "TP", cm.tp / total, tech, n_samples, tool))
        data.append((covg, "FN", cm.fn / total, tech, n_samples, tool))
        data.append((covg, "TN", cm.tn / total, tech, n_samples, tool))

summary = pd.DataFrame(
    data, columns=["coverage", "classification", "proportion", "technology", "total", "tool"]
)

# %% [markdown]
# Effect of Nanopore read depth on mykrobe phenotype prediction. Each point indicates the proportion (y-axis) of classifications of that type at the read depth (x-axis). Read depth is "binned". That is, read depth 40 is all samples with a read depth greater than 40 and less than or equal to 50. FP - false positive; TN - true negative; etc.

# %%
with sns.plotting_context(rc={"lines.linewidth": 1.1}):
    fig, axes = plt.subplots(nrows=len(TOOLS), figsize=(13, 8), dpi=300, sharex=True)
    
    for tool, ax in zip(TOOLS, axes.flatten()):
        x = "coverage"
        y = "proportion"
        hue = "classification"
        tech = "nanopore"
        linestyles = ["solid", "dotted", "dashed", "dashdot"]
        data = summary.query("technology == @tech and tool == @tool")
        sns.pointplot(
            data=data,
            x=x,
            y=y,
            hue=hue,
            ax=ax,
            linestyles=linestyles,
            alpha=0.9,
        )
        ax.set_xlabel("")
        ax.set(title=f"tool = {tool}")

        ax2 = ax.twinx()
        sns.barplot(data=data, x=x, y="total", ax=ax2, color=blue, alpha=0.2)
        ax2.set_ylabel("number of samples")
        ax.legend(loc="center left", fontsize=12)
        
    xlabels = ax2.get_xticklabels()
    xlabels[-1].set_text(xlabels[-1].get_text() + "+")
    ax2.set_xticklabels(xlabels)
    ax.set_xlabel("read depth")
    ax.get_legend().remove()
    plt.tight_layout()

# %%
fig.savefig(snakemake.output.pheno_coverage_plot)

# %% [markdown]
# # Concordance of mykrobe Nanopore resistance prediction with Illumina
# Having proven mykrobe's ability to predict resistance for select drugs with ONT, we look at the concordance of ONT-based predictions with Illumina-based ones. We aim to answer to main questions here: 1) Are ONT predictions concordant with Illumina and 2) does ONT depth of coverage impact prediction capabilities and, if so, what is the coverage threshold for this impact?
# We will also discuss the causes for any discrepencies and look to COMPASS/bcftools calls for adjudication if possible.
#
# For the figure/table of this section it might suffice to just have a table like the one in Table 1. of the recent mykrobe paper with a row for each drug and columns showing TPs, FNs etc. along with VME (95% CI), ME (95% CI), PPV and NPV

# %%
classes = sorted(set(calls["classification"]))
conf_mxs = defaultdict()

for drug, tool, tech in product(DRUGS, TOOLS, TECHS):
    if (tech, tool) == ("illumina", "mykrobe"):
        continue
    s = calls.query("drug == @drug and tool == @tool and tech == @tech").value_counts(subset=["classification"])
    cm = ConfusionMatrix.from_series(s)
    conf_mxs[(drug, tech, tool)] = cm

metrics = []
for (drug, tech, tool), cm in conf_mxs.items():
    #     sensitivity = cm.sensitivity()
    #     specificity = cm.specificity()
    ppv = cm.ppv()[0]
    npv = cm.npv()[0]
    vme = cm.fnr()[0]
    me = cm.fpr()[0]
    metrics.append((drug, ppv, npv, vme, me, tech, tool))

summary_cols = ["drug", "PPV", "NPV", "FNR", "FPR", "tech", "tool"]

summary = pd.DataFrame(metrics, columns=summary_cols).melt(
    id_vars=["drug", "tool", "tech"], var_name="metric"
)
table = summary.set_index(["drug", "tool", "tech", "metric"])["value"].unstack().reset_index()
table = table[summary_cols]

counts = calls.groupby(["drug", "tool", "tech", "classification"])["sample"].count()
for clf in ["TP", "FP", "FN", "TN"]:
    table[clf] = 0

for i, row in table.iterrows():
    ix = (row["drug"], row["tech"], row["tool"])
    cm = conf_mxs[ix]
    table.at[i, "TP"] = cm.tp
    table.at[i, "FP"] = cm.fp
    table.at[i, "TN"] = cm.tn
    table.at[i, "FN"] = cm.fn
    
for k in ["drug", "tech", "tool"]:
    table[k] = table[k].str.capitalize()

table
# Out:
# metric           drug       PPV       NPV       FNR       FPR      tech  \
# 0            Amikacin  0.928571  1.000000  0.000000  0.007246  Illumina
# 1            Amikacin  0.928571  1.000000  0.000000  0.007246  Nanopore
# 2            Amikacin  0.928571  1.000000  0.000000  0.007246  Nanopore
# 3         Capreomycin  0.928571  1.000000  0.000000  0.007246  Illumina
# 4         Capreomycin  0.928571  1.000000  0.000000  0.007246  Nanopore
# 5         Capreomycin  0.928571  1.000000  0.000000  0.007246  Nanopore
# 6       Ciprofloxacin  1.000000  1.000000  0.000000  0.000000  Illumina
# 7       Ciprofloxacin  1.000000  1.000000  0.000000  0.000000  Nanopore
# 8       Ciprofloxacin  1.000000  1.000000  0.000000  0.000000  Nanopore
# 9          Ethambutol  1.000000  0.989796  0.018519  0.000000  Illumina
# 10         Ethambutol  1.000000  0.989796  0.018519  0.000000  Nanopore
# 11         Ethambutol  1.000000  1.000000  0.000000  0.000000  Nanopore
# ...

# %%
print(table.to_markdown(index=False))
# Out:
# | drug          |      PPV |      NPV |       FNR |        FPR | tech     | tool    |   TP |   FP |   FN |   TN |
# |:--------------|---------:|---------:|----------:|-----------:|:---------|:--------|-----:|-----:|-----:|-----:|
# | Amikacin      | 0.928571 | 1        | 0         | 0.00724638 | Illumina | Drprg   |   13 |    1 |    0 |  137 |
# | Amikacin      | 0.928571 | 1        | 0         | 0.00724638 | Nanopore | Drprg   |   13 |    1 |    0 |  137 |
# | Amikacin      | 0.928571 | 1        | 0         | 0.00724638 | Nanopore | Mykrobe |   13 |    1 |    0 |  137 |
# | Capreomycin   | 0.928571 | 1        | 0         | 0.00724638 | Illumina | Drprg   |   13 |    1 |    0 |  137 |
# | Capreomycin   | 0.928571 | 1        | 0         | 0.00724638 | Nanopore | Drprg   |   13 |    1 |    0 |  137 |
# | Capreomycin   | 0.928571 | 1        | 0         | 0.00724638 | Nanopore | Mykrobe |   13 |    1 |    0 |  137 |
# ...

# %%
print(table.to_latex(index=False))
# Out:
# \begin{tabular}{lrrrrllrrrr}
# \toprule
#          drug &      PPV &      NPV &      FNR &      FPR &     tech &    tool &  TP &  FP &  FN &  TN \\
# \midrule
#      Amikacin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Illumina &   Drprg &  13 &   1 &   0 & 137 \\
#      Amikacin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Nanopore &   Drprg &  13 &   1 &   0 & 137 \\
#      Amikacin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Nanopore & Mykrobe &  13 &   1 &   0 & 137 \\
#   Capreomycin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Illumina &   Drprg &  13 &   1 &   0 & 137 \\
#   Capreomycin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Nanopore &   Drprg &  13 &   1 &   0 & 137 \\
#   Capreomycin & 0.928571 & 1.000000 & 0.000000 & 0.007246 & Nanopore & Mykrobe &  13 &   1 &   0 & 137 \\
# Ciprofloxacin & 1.000000 & 1.000000 & 0.000000 & 0.000000 & Illumina &   Drprg &  16 &   0 &   0 & 135 \\
# ...

# %%
rows = []
ci_str = (
    lambda tup: f"{tup[0]:.1%} ({tup[1]*100:.1f}-{tup[2]:.1%})"
    if tup[0] is not None
    else "-"
)
for i, row in table.iterrows():
    cm = ConfusionMatrix(tp=row["TP"], fp=row["FP"], tn=row["TN"], fn=row["FN"])
    npv = cm.npv()
    ppv = cm.ppv()
    vme = cm.fnr()
    me = cm.fpr()
    fn_str = f"{cm.fn}({cm.num_positive()})"
    fp_str = f"{cm.fp}({cm.num_negative()})"
    rows.append(
        (row["drug"], row["tool"], row["tech"], fn_str, fp_str, ci_str(vme), ci_str(me), ci_str(ppv), ci_str(npv))
    )
pretty_cols = [
    "Drug",
    "Tool",
    "Technology",
    "FN(R)",
    "FP(S)",
    "FNR(95% CI)",
    "FPR(95% CI)",
    "PPV(95% CI)",
    "NPV(95% CI)",
]
table = pd.DataFrame(rows, columns=pretty_cols)
table
# Out:
#              Drug     Tool Technology   FN(R)    FP(S)         FNR(95% CI)  \
# 0        Amikacin    Drprg   Illumina   0(13)   1(138)    0.0% (0.0-22.8%)
# 1        Amikacin    Drprg   Nanopore   0(13)   1(138)    0.0% (0.0-22.8%)
# 2        Amikacin  Mykrobe   Nanopore   0(13)   1(138)    0.0% (0.0-22.8%)
# 3     Capreomycin    Drprg   Illumina   0(13)   1(138)    0.0% (0.0-22.8%)
# 4     Capreomycin    Drprg   Nanopore   0(13)   1(138)    0.0% (0.0-22.8%)
# 5     Capreomycin  Mykrobe   Nanopore   0(13)   1(138)    0.0% (0.0-22.8%)
# 6   Ciprofloxacin    Drprg   Illumina   0(16)   0(135)    0.0% (0.0-19.4%)
# 7   Ciprofloxacin    Drprg   Nanopore   0(16)   0(135)    0.0% (0.0-19.4%)
# 8   Ciprofloxacin  Mykrobe   Nanopore   0(16)   0(135)    0.0% (0.0-19.4%)
# 9      Ethambutol    Drprg   Illumina   1(54)    0(97)     1.9% (0.3-9.8%)
# 10     Ethambutol    Drprg   Nanopore   1(54)    0(97)     1.9% (0.3-9.8%)
# ...

# %% [markdown]
# ## Table 2 Comparison of Nanopore drug resistance predictions with Illumina predictions
#
# For this comparison, we assume the mykrobe resistance prediction from Illumina data is correct and evaluate the Nanopore prediction accordingly.
#
# FN=false negative; R=number of resistant samples; FP=false positive; S=number of susceptible samples; FNR=false negative rate; FPR=false positive rate; PPV=positive predictive value; NPV=negative predictive value; CI=Wilson score confidence interval

# %%
print(table.to_markdown(index=False))
# Out:
# | Drug          | Tool    | Technology   | FN(R)   | FP(S)   | FNR(95% CI)        | FPR(95% CI)       | PPV(95% CI)          | NPV(95% CI)          |
# |:--------------|:--------|:-------------|:--------|:--------|:-------------------|:------------------|:---------------------|:---------------------|
# | Amikacin      | Drprg   | Illumina     | 0(13)   | 1(138)  | 0.0% (0.0-22.8%)   | 0.7% (0.1-4.0%)   | 92.9% (68.5-98.7%)   | 100.0% (97.3-100.0%) |
# | Amikacin      | Drprg   | Nanopore     | 0(13)   | 1(138)  | 0.0% (0.0-22.8%)   | 0.7% (0.1-4.0%)   | 92.9% (68.5-98.7%)   | 100.0% (97.3-100.0%) |
# | Amikacin      | Mykrobe | Nanopore     | 0(13)   | 1(138)  | 0.0% (0.0-22.8%)   | 0.7% (0.1-4.0%)   | 92.9% (68.5-98.7%)   | 100.0% (97.3-100.0%) |
# | Capreomycin   | Drprg   | Illumina     | 0(13)   | 1(138)  | 0.0% (0.0-22.8%)   | 0.7% (0.1-4.0%)   | 92.9% (68.5-98.7%)   | 100.0% (97.3-100.0%) |
# ...

# %%
print(table.to_latex(index=False))
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#          Drug &    Tool & Technology &  FN(R) &   FP(S) &        FNR(95\% CI) &       FPR(95\% CI) &          PPV(95\% CI) &          NPV(95\% CI) \\
# \midrule
#      Amikacin &   Drprg &   Illumina &  0(13) &  1(138) &   0.0\% (0.0-22.8\%) &   0.7\% (0.1-4.0\%) &   92.9\% (68.5-98.7\%) & 100.0\% (97.3-100.0\%) \\
#      Amikacin &   Drprg &   Nanopore &  0(13) &  1(138) &   0.0\% (0.0-22.8\%) &   0.7\% (0.1-4.0\%) &   92.9\% (68.5-98.7\%) & 100.0\% (97.3-100.0\%) \\
#      Amikacin & Mykrobe &   Nanopore &  0(13) &  1(138) &   0.0\% (0.0-22.8\%) &   0.7\% (0.1-4.0\%) &   92.9\% (68.5-98.7\%) & 100.0\% (97.3-100.0\%) \\
#   Capreomycin &   Drprg &   Illumina &  0(13) &  1(138) &   0.0\% (0.0-22.8\%) &   0.7\% (0.1-4.0\%) &   92.9\% (68.5-98.7\%) & 100.0\% (97.3-100.0\%) \\
#   Capreomycin &   Drprg &   Nanopore &  0(13) &  1(138) &   0.0\% (0.0-22.8\%) &   0.7\% (0.1-4.0\%) &   92.9\% (68.5-98.7\%) & 100.0\% (97.3-100.0\%) \\
# ...

# %%
table.to_csv(snakemake.output.illumina_concordance_csv, na_rep="-", index=False)

# %% [markdown]
# ## Figure 4
# Number of resistant (left) and susceptible (right) genotypes correctly identified by mykrobe from Illumina (blue) and Nanopore (purple) data from the same samples. The genotypes are predictions from mykrobe with Illumina data. The red bars indicate missed (FN) or incorrect (FP) predictions. The x-axis shows the drugs with available phenotype data that mykrobe also makes predictions for. E - ethambutol; H - isoniazid; Z - pyrazinamide; R - rifampicin; S - streptomycin; Km - kanamycin; Am - amikacin; Ofx - ofloxacin; Cm - capreomycin; Mfx - moxifloxacin.

# %%
fig, axes = plt.subplots(ncols=2, figsize=(13, 8), dpi=300, sharey=True)
axR = axes.flatten()[0]
axS = axes.flatten()[1]

# plot details
bar_width = 0.2
epsilon = 0.05
line_width = 0.5
alpha = 1.0
hatch = "////"

all_positions = []
for i, (tech, tool) in enumerate(product(TECHS, TOOLS)):
    if (tech, tool) == ("illumina", "mykrobe"):
        continue
        
    tps = [conf_mxs[(d, tech, tool)].tp for d in DRUGS]
    fps = [conf_mxs[(d, tech, tool)].fp for d in DRUGS]
    tns = [conf_mxs[(d, tech, tool)].tn for d in DRUGS]
    fns = [conf_mxs[(d, tech, tool)].fn for d in DRUGS]
    
    positions = [p + ((bar_width + epsilon) * i) for p in np.arange(len(tps))]
    all_positions.append(positions)
    
    colour = cmap[tool]

    # resistance bar plots
    tps_bar = axR.bar(
        positions,
        tps,
        bar_width,
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    fns_bar = axR.bar(
        positions,
        fns,
        bar_width,
        bottom=tps,
        color=red,
        edgecolor=edgecol,
        linewidth=line_width,
    )

    # susceptible bar plots
    tns_bar = axS.bar(
        positions,
        tns,
        bar_width,
        color=colour,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    fps_bar = axS.bar(
        positions,
        fps,
        bar_width,
        bottom=tns,
        color=red,
        edgecolor=edgecol,
        linewidth=line_width,
    )
    
    if tech == "illumina":
        for bar in tps_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in fps_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in fns_bar.patches:
            bar.set_hatch(hatch)
            
        for bar in tns_bar.patches:
            bar.set_hatch(hatch)
    else:
        tps_bar.set_label(tool)

    if i == 0:
        fps_bar.set_label("FP")
        fns_bar.set_label("FN")
        
labels = [drug_abbrev[d.lower()] for d in DRUGS]
label_pos = [np.mean(ps) for ps in zip(*all_positions)]
plt.xticks(label_pos, labels, rotation=90)
axR.set_ylabel("samples")
axR.set_xticks(label_pos)
axR.set_xticklabels(axS.get_xticklabels(), rotation=90)
axR.set_title("Resistant")
axS.set_title("Susceptible")

axS.legend(loc="best", prop={"size": 11})
leghandles, leglabels = axR.get_legend_handles_labels()
from matplotlib.patches import Patch
hatch_leghandle = Patch(facecolor='white', hatch=hatch)
leghandles.insert(3, hatch_leghandle)
leglabels.insert(3, "Illumina")
leglabels.insert(3, leglabels.pop(1))
leghandles.insert(3, leghandles.pop(1))
axR.legend(leghandles, leglabels, loc="best", prop={"size": 11})

sns.despine()
plt.tight_layout()

# %%
fig.savefig(snakemake.output.geno_concordance_plot)
