# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/hps/software/users/iqbal/mbhall/miniconda3/envs/h2h/lib/python3.9/site-packages', '/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/workflow/notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95q]\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c@/hps/nobackup/iqbal/mbhall/tech_wars/data/QC/report/coverage.csv\x94\x8c\x19../../docs/phenotypes.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-7.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_109.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-28.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_135.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-43.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-31.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-50.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_110.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-1.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-22.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-36.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_120.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_107.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-51.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-6.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-53.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_130.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-34.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-40.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_143.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-25.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-30.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-33.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_111.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_102.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-48.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-47.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_116.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_150.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-39.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-44.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_132.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_128.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-46.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_112.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-12.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_154.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_126.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-5.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_122.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_133.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-16.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_140.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_134.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_123.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-42.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_127.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_117.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-1.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_124.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_151.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_139.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_121.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_113.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-18.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_131.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-38.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_104.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-46.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-25.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_129.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_118.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_136.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-50.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-11.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-41.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-2.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-19.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-10.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-3.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-8.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-15.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_105.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_125.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_144.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-14.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_141.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_103.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_115.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_137.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-17.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-13.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-20.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_142.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_148.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-54.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_106.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_1-32.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_2-53.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/madagascar/mada_152.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R26791.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21363.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30234.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R36431.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27252.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R29816.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R29598.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30078.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R24100.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R31095.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R18043.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R18040.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27937.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30396.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27657.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30420.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21839.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28182.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20896.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23887.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R37765.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R30215.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21893.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R27725.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21408.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28012.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28703.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R21770.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20260.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R25048.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23146.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R32929.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R23571.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20574.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28980.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R24120.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R28581.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R15311.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R22601.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R20983.mykrobe.csv\x94\x8c\x88/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/south_africa/R26778.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/17_616026.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/17_616156.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0621851.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622057.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622158.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622224.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622267.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622291.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622300.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622312.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622363.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622365.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622431.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622434.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622446.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622455.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622456.mykrobe.csv\x94\x8c\x8a/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_0622465.mykrobe.csv\x94\x8c\x89/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/concordance/mykrobe/nanopore/birmingham/18_620606.mykrobe.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x08coverage\x94K\x00N\x86\x94\x8c\nphenosheet\x94K\x01N\x86\x94\x8c\x0bconcordance\x94K\x02K\x98\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\xad\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\xb3)}\x94\x8c\x05_name\x94h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bh\xa5h\nh\xa7h\x0bh\xa9h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9h:h;h<h=h>h?h@hAhBhChDhEhFhGhHhIhJhKhLhMhNhOhPhQhRhShThUhVhWhXhYhZh[h\\h]h^h_h`hahbhchdhehfhghhhihjhkhlhmhnhohphqhrhshthuhvhwhxhyhzh{h|h}h~h\x7fh\x80h\x81h\x82h\x83h\x84h\x85h\x86h\x87h\x88h\x89h\x8ah\x8bh\x8ch\x8dh\x8eh\x8fh\x90h\x91h\x92h\x93h\x94h\x95h\x96h\x97h\x98h\x99h\x9ah\x9bh\x9ch\x9dh\x9eh\x9fh\xa0h\xa1e}\x94(h\xa3}\x94h\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8ce/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/available_dst.png\x94\x8cm/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_concordance.png\x94\x8cm/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_concordance.csv\x94\x8cl/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/illumina_concordance.csv\x94\x8cj/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/phenotype_coverage.png\x94e}\x94(h\xa3}\x94(\x8c\x08dst_data\x94K\x00N\x86\x94\x8c\x16pheno_concordance_plot\x94K\x01N\x86\x94\x8c\x15pheno_concordance_csv\x94K\x02N\x86\x94\x8c\x18illumina_concordance_csv\x94K\x03N\x86\x94\x8c\x13pheno_coverage_plot\x94K\x04N\x86\x94uh\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bh\xd6h\xcfh\xd8h\xd0h\xdah\xd1h\xdch\xd2h\xdeh\xd3ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94\x8f\x94(\x8c\x0cmoxifloxacin\x94\x8c\x0cpyrazinamide\x94\x90a}\x94(h\xa3}\x94\x8c\x0cignore_drugs\x94K\x00N\x86\x94sh\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bh\xf2h\xedub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h\xa3}\x94h\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01e}\x94(h\xa3}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94uh\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bj\x13\x01\x00\x00K\x01j\x15\x01\x00\x00K\x01ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cl/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/results/figures/analysis.processed.ipynb\x94a}\x94(h\xa3}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\xab]\x94(h\xadh\xaeeh\xadh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xadsNt\x94bh\xaeh\xb1h\xb3\x85\x94R\x94(h\xb3)}\x94h\xb7h\xaesNt\x94bj\'\x01\x00\x00j$\x01\x00\x00ub\x8c\x06config\x94}\x94(\x8c\x0bsamplesheet\x94\x8c\x1a../../docs/samplesheet.csv\x94\x8c\nphenosheet\x94\x8c\x19../../docs/phenotypes.csv\x94\x8c\x11mykrobe_panel_url\x94\x8c/https://ndownloader.figshare.com/files/14120198\x94\x8c\tmatch_len\x94K\x05\x8c\x07padding\x94Kd\x8c\x07filters\x94}\x94(\x8c\x08min_covg\x94K\x03\x8c\x0fmin_strand_bias\x94G?\x84z\xe1G\xae\x14{\x8c\x07min_frs\x94G?\xe8\x00\x00\x00\x00\x00\x00\x8c\tmax_indel\x94K\x14\x8c\x0bmin_gt_conf\x94}\x94(\x8c\x08nanopore\x94K\x05\x8c\x08illumina\x94K\x05uu\x8c\ncontainers\x94}\x94(\x8c\x04base\x94\x8c\x11docker://bash:5.1\x94\x8c\x07mykrobe\x94\x8c=docker://quay.io/biocontainers/mykrobe:0.10.0--py38h8e3bb3f_0\x94\x8c\x05conda\x94\x8c%docker://continuumio/miniconda3:4.9.2\x94\x8c\x05drprg\x94\x8c\'docker://quay.io/mbhall88/drprg:0ef9e82\x94\x8c\x05mafft\x94\x8c6docker://quay.io/biocontainers/mafft:7.475--h516909a_0\x94uu\x8c\x04rule\x94\x8c\x0fanalyse_results\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cV/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/workflow/notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir('/hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction');
######## snakemake preamble end #########

# %% [markdown]
# # Evaluation of Nanopore-base drug resistance prediction
#
# This notebook contains the figures and tables for the drug resistance prediction component of our paper *Nanopore sequencing for _Mycobacterium tuberculosis_ public health applications*

# %%
import pandas as pd
from pathlib import Path
from typing import Tuple
from itertools import product
from collections import defaultdict
import pandas as pd
import numpy as np
from scipy import stats
from math import sqrt
from enum import Enum
from dataclasses import dataclass
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator, AutoMinorLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import seaborn as sns
import upsetplot

phenosheet = snakemake.input.phenosheet
plt.style.use("ggplot")
CONF = snakemake.params.get("confidence", 0.95)

# %% [markdown]
# Load the concordance data. This gives us the mykrobe Illumina and Nanopore calls for each sample-drug combination.

# %%
coverages = np.arange(start=25, stop=155, step=5)

# %%
covdf = pd.read_csv(snakemake.input.coverage, index_col="sample")

# %%
concordance_files = [Path(p) for p in snakemake.input.concordance]

# %%
frames = []
for p in concordance_files:
    sample, tool = p.name.split(".")[0:2]
    table = pd.read_csv(p)
    table["sample"] = sample
    table["tool"] = tool
    table.rename(
        columns={"true_call": "Illumina", "test_call": "Nanopore"}, inplace=True
    )
    frames.append(table)

# %%
calls = pd.concat(frames)
calls.reset_index(drop=True, inplace=True)
valid_samples = set(calls["sample"])

# %%
calls
# Out:
#                drug classification Illumina Nanopore     sample     tool
# 0         Ofloxacin             TN        S        S   mada_1-7  mykrobe
# 1      Moxifloxacin             TN        S        S   mada_1-7  mykrobe
# 2         Isoniazid             TP        R        R   mada_1-7  mykrobe
# 3         Kanamycin             TN        S        S   mada_1-7  mykrobe
# 4        Ethambutol             TN        S        S   mada_1-7  mykrobe
# ...             ...            ...      ...      ...        ...      ...
# 1645  Ciprofloxacin             TN        S        S  18_620606  mykrobe
# 1646   Pyrazinamide             TN        S        S  18_620606  mykrobe
# 1647     Rifampicin             TN        S        S  18_620606  mykrobe
# 1648       Amikacin             TN        S        S  18_620606  mykrobe
# 1649    Capreomycin             TN        S        S  18_620606  mykrobe
#
# [1650 rows x 6 columns]

# %% [markdown]
# Load the phenotype information

# %%
pheno = pd.read_csv(phenosheet).melt(
    id_vars=["sample"], var_name="drug", value_name="phenotype"
)
arr = []
for r in pheno["phenotype"]:
    if pd.isna(r):
        arr.append(r)
    elif r.upper() in ("R", "S"):
        arr.append(r.upper())
    else:
        arr.append(None)
pheno["phenotype"] = arr
pheno = pheno.loc[pheno["sample"].isin(valid_samples)]
pheno.set_index(["sample", "drug"], drop=False, inplace=True)

# %%
pheno
# Out:
#                          sample          drug phenotype
# sample   drug
# mada_102 streptomycin  mada_102  streptomycin         S
# mada_103 streptomycin  mada_103  streptomycin         S
# mada_104 streptomycin  mada_104  streptomycin         S
# mada_105 streptomycin  mada_105  streptomycin         S
# mada_106 streptomycin  mada_106  streptomycin         S
# ...                         ...           ...       ...
# R31095   ethionamide     R31095   ethionamide       NaN
#          ethionamide     R31095   ethionamide       NaN
# R32929   ethionamide     R32929   ethionamide       NaN
# R36431   ethionamide     R36431   ethionamide         R
# R37765   ethionamide     R37765   ethionamide       NaN
#
# [2860 rows x 3 columns]

# %%
mykrobe_drugs = set(calls["drug"])

# %%
d = {}
for drug in map(str.lower, mykrobe_drugs):
    d[drug.upper()] = list(pheno.query("drug == @drug").dropna()["sample"])
#     lpa = drug + "-lpa"
#     d[lpa.upper()] = list(pheno.query("drug == @lpa").dropna()["sample"])

# %%
upset_data = upsetplot.from_contents(d)

# %% [markdown]
# ## Figure 1
# Culture-based drug susceptibility data available for samples. Each row is a drug, and the columns represent a set of samples that have phenotype information for those drugs with a filled cell. The top panel shows the number of samples in the set for that combination of drugs. The bar plot in the left panel shows the number of samples with phenotype information for that drug.

# %%
fig, ax = plt.subplots()
p = upsetplot.plot(
    upset_data,
    fig=fig,
    sort_by="cardinality",
    orientation="horizontal",
)
p["intersections"].set_ylabel("count")
ax.axis("off")
# fig.set_figwidth(8)
# fig.set_figheight(10)
fig.set_dpi(300)

# %%
fig.savefig(snakemake.output.dst_data)

# %% [markdown]
# ## Resistance prediction performance of mykrobe
# mykrobe has been rigorously evaluated on datasets which much better/broader phenotype availability. However, it's prediction ability on ONT data has only been validated with 5 samples. We look to validate it's performance on this dataset's Illumina and ONT data, for those drugs/samples where phenotype data is available.
# We will also discuss the causes for any discrepencies and look to COMPASS/bcftools calls for adjudication if possible.
#
# The figure for this section will basically be a copy of [5c/d from the mykrobe nature comms paper](https://www.nature.com/articles/ncomms10063#Fig5) (side-by-side bar charts showing resistant/susceptible samples, with stacked bars indicating FPs and FNs)

# %%
# taken from https://apps.who.int/iris/bitstream/handle/10665/130918/9789241548809_eng.pdf?sequence=1&isAllowed=y
drug_abbrev = {
    "ethambutol": "E",
    "isoniazid": "H",
    "pyrazinamide": "Z",
    "rifampicin": "R",
    "streptomycin": "S",
    "kanamycin": "Km",
    "amikacin": "Am",
    "ofloxacin": "Ofx",
    "capreomycin": "Cm",
    "moxifloxacin": "Mfx",
    "ciprofloxacin": "Cfx",
}
ignore_drugs = snakemake.params.get("ignore_drugs", set())


class Prediction(Enum):
    Resistant = "R"
    Susceptible = "S"
    MinorResistance = "r"
    Unknown = "U"
    Failed = "F"

    def __str__(self) -> str:
        return self.value


class Classifier(Enum):
    TruePositive = "TP"
    FalsePositive = "FP"
    TrueNegative = "TN"
    FalseNegative = "FN"

    def __str__(self) -> str:
        return self.value

    @staticmethod
    def from_predictions(y_true: Prediction, y_pred: Prediction) -> "Classifier":
        if y_true is Prediction.Susceptible:
            return (
                Classifier.TrueNegative
                if y_pred is Prediction.Susceptible
                else Classifier.FalsePositive
            )
        elif y_true is Prediction.Resistant:
            return (
                Classifier.TruePositive
                if y_pred in (Prediction.Resistant, Prediction.MinorResistance)
                else Classifier.FalseNegative
            )
        else:
            raise NotImplementedError(
                "Don't know how to classify minor resistant calls yet"
            )


@dataclass
class ConfusionMatrix:
    tp: int = 0
    tn: int = 0
    fp: int = 0
    fn: int = 0

    def ravel(self) -> Tuple[int, int, int, int]:
        """Return the matrix as a flattened tuple.
        The order of return is TN, FP, FN, TP
        """
        return self.tn, self.fp, self.fn, self.tp

    def as_matrix(self) -> np.ndarray:
        """Returns a 2x2 matrix [[TN, FP], [FN, TP]]"""
        return np.array([[self.tn, self.fp], [self.fn, self.tp]])

    def num_positive(self) -> int:
        """Number of TPs and FNs - i.e. actual condition positive"""
        return self.tp + self.fn

    def num_negative(self) -> int:
        """Number of TNs and FPs - i.e. actual condition negative"""
        return self.tn + self.fp

    def ppv(self) -> Tuple[float, float, float]:
        """Also known as precision"""
        try:
            ppv = self.tp / (self.tp + self.fp)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tp, n_f=self.fp)
            return ppv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def npv(self) -> Tuple[float, float, float]:
        """Negative predictive value"""
        try:
            npv = self.tn / (self.tn + self.fn)
            lwr_bound, upr_bound = confidence_interval(n_s=self.tn, n_f=self.fn)
            return npv, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def sensitivity(self) -> float:
        """Also known as recall and true positive rate (TPR)"""
        try:
            return self.tp / self.num_positive()
        except ZeroDivisionError:
            return None

    def specificity(self) -> float:
        """Also known as selectivity and true negative rate (TNR)"""
        try:
            return self.tn / self.num_negative()
        except ZeroDivisionError:
            return None

    def fnr(self) -> Tuple[float, float, float]:
        """False negative rate or VME (very major error rate)"""
        try:
            fnr = self.fn / self.num_positive()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fn, n_f=self.tp)
            return fnr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def fpr(self) -> Tuple[float, float, float]:
        """False positive rate or ME (major error rate)"""
        try:
            fpr = self.fp / self.num_negative()
            lwr_bound, upr_bound = confidence_interval(n_s=self.fp, n_f=self.tn)
            return fpr, lwr_bound, upr_bound
        except ZeroDivisionError:
            return [None, None, None]

    def f_score(self, beta: float = 1.0) -> float:
        """Harmonic mean of precision and recall.
        When beta is set to 0, you get precision. When beta is set to 1, you get the
        unweighted F-score which is the harmonic mean of precision and recall. Setting
        beta to 2 weighs recall twice as much as precision. Setting beta to 0.5 weighs
        precision twice as much as recall.
        """
        ppv = self.precision()
        tpr = self.recall()
        if ppv is None or tpr is None:
            return None
        beta2 = beta ** 2

        return ((beta2 + 1) * ppv * tpr) / ((beta2 * ppv) + tpr)

    @staticmethod
    def from_series(s: pd.Series) -> "ConfusionMatrix":
        tp = s.get("TP", 0)
        fp = s.get("FP", 0)
        fn = s.get("FN", 0)
        tn = s.get("TN", 0)
        return ConfusionMatrix(tp=tp, fn=fn, fp=fp, tn=tn)


def confidence_interval(n_s: int, n_f: int, conf: float = CONF) -> Tuple[float, float]:
    """Calculate the Wilson score interval.
    Equation take from https://en.wikipedia.org/wiki/Binomial_proportion_confidence_interval#Wilson_score_interval
    n_s: Number of successes or, in the case of confusion matrix statistics, the numerator
    n_f: Number of failures or, in the case of confusion matrix statistics, the denominator minus the numerator
    conf: the confidence level. i.e. 0.95 is 95% confidence
    """
    n = n_f + n_s
    z = stats.norm.ppf(1 - (1 - conf) / 2)  # two-sided
    z2 = z ** 2
    nz2 = n + z2
    A = (n_s + (0.5 * z2)) / nz2
    B = z / nz2
    C = sqrt(((n_s * n_f) / n) + (z2 / 4))
    CI = B * C
    return A - CI, A + CI


def round_up_to_base(x, base=10):
    return int(x + (base - x) % base)


def round_down_to_base(x, base=10):
    return int(x - (x % base))

# %%
pheno_clf = []
for ix, row in calls.iterrows():
    ill_pred = Prediction(row["Illumina"])
    ont_pred = Prediction(row["Nanopore"])
    drug = row["drug"].lower()
    if drug in ignore_drugs:
        continue

    sample = row["sample"]
    try:
        ph = pheno.loc[(sample, drug), "phenotype"]
        if pd.isna(ph).all():
            continue
        else:
            truth = Prediction(ph[0])
    except KeyError:
        continue
    ill_clf = Classifier.from_predictions(truth, ill_pred)
    ill_covg = covdf.loc[sample]["illumina_covg"]
    pheno_clf.append((sample, drug, str(ill_clf), "illumina", ill_covg))
    ont_clf = Classifier.from_predictions(truth, ont_pred)
    ont_covg = covdf.loc[sample]["nanopore_covg"]
    pheno_clf.append((sample, drug, str(ont_clf), "nanopore", ont_covg))
# Out:
# /hps/nobackup/iqbal/mbhall/tech_wars/analysis/resistance_prediction/.snakemake/conda/279bd785543486ebfb5da5c88a20bff3/lib/python3.8/site-packages/pandas/core/indexing.py:889: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)

# %%
clf_df = pd.DataFrame(
    pheno_clf, columns=["sample", "drug", "classification", "technology", "coverage"]
)

# %%
pheno_cms = defaultdict(dict)

for drug, tech in product(set(clf_df["drug"]), set(clf_df["technology"])):
    s = clf_df.query("drug == @drug and technology == @tech").value_counts(
        subset=["classification"]
    )
    cm = ConfusionMatrix.from_series(s)
    pheno_cms[drug][tech] = cm

# %%
metrics = []
for drug, technology in pheno_cms.items():
    for tech, cm in technology.items():
        #         sensitivity = cm.sensitivity()
        #         specificity = cm.specificity()
        ppv = cm.ppv()[0]
        npv = cm.npv()[0]
        vme = cm.fnr()[0]
        me = cm.fpr()[0]
        metrics.append((drug, tech, ppv, npv, vme, me))

summary_cols = [
    "drug",
    "tech",
    "PPV",
    "NPV",
    "FNR",
    "FPR",
]

summary = pd.DataFrame(
    metrics,
    columns=summary_cols,
).melt(id_vars=["drug", "tech"], var_name="metric")

# %% [markdown]
# ## Figure 2
# Number of resistant (left) and susceptible (right) phenotypes correctly identified by mykrobe from Illumina (blue) and Nanopore (purple) data from the same samples. The red bars indicate missed (FN) or incorrect (FP) predictions. The x-axis shows the drugs with available phenotype data that mykrobe also makes predictions for. E - ethambutol; H - isoniazid; Z - pyrazinamide; R - rifampicin; S - streptomycin; Km - kanamycin; Am - amikacin; Ofx - ofloxacin; Cm - capreomycin; Mfx - moxifloxacin.

# %%
fig, axes = plt.subplots(ncols=2, figsize=(13, 8), dpi=300, sharey=True)
axR = axes.flatten()[0]
axS = axes.flatten()[1]
# make up some fake data
drugs = sorted(pheno_cms.keys())
ill_tps = [pheno_cms[d]["illumina"].tp for d in drugs]
ill_fns = [pheno_cms[d]["illumina"].fn for d in drugs]
ill_tns = [pheno_cms[d]["illumina"].tn for d in drugs]
ill_fps = [pheno_cms[d]["illumina"].fp for d in drugs]
ont_tps = [pheno_cms[d]["nanopore"].tp for d in drugs]
ont_fns = [pheno_cms[d]["nanopore"].fn for d in drugs]
ont_tns = [pheno_cms[d]["nanopore"].tn for d in drugs]
ont_fps = [pheno_cms[d]["nanopore"].fp for d in drugs]

ggplot_cm = plt.rcParams["axes.prop_cycle"].by_key()["color"]
red = ggplot_cm[0]
blue = ggplot_cm[1]
purple = ggplot_cm[2]
edgecol = "black"

# plot details
bar_width = 0.35
epsilon = 0.05
line_width = 0.5
alpha = 1.0
ill_positions = np.arange(len(ill_tps))
ont_positions = ill_positions + bar_width + epsilon

# resistance bar plots
ill_tps_bar = axR.bar(
    ill_positions,
    ill_tps,
    bar_width,
    color=blue,
    edgecolor=edgecol,
    linewidth=line_width,
    label="Illumina",
)
ill_fns_bar = axR.bar(
    ill_positions,
    ill_fns,
    bar_width,
    bottom=ill_tps,
    color=red,
    edgecolor=edgecol,
    linewidth=line_width,
)

ont_tps_bar = axR.bar(
    ont_positions,
    ont_tps,
    bar_width,
    color=purple,
    edgecolor=edgecol,
    linewidth=line_width,
    label="Nanopore",
)
ont_fns_bar = axR.bar(
    ont_positions,
    ont_fns,
    bar_width,
    bottom=ont_tps,
    color=red,
    edgecolor=edgecol,
    linewidth=line_width,
    label="FN",
)

# susceptible bar plots
ill_tns_bar = axS.bar(
    ill_positions,
    ill_tns,
    bar_width,
    color=blue,
    edgecolor=edgecol,
    linewidth=line_width,
)
ill_fps_bar = axS.bar(
    ill_positions,
    ill_fps,
    bar_width,
    bottom=ill_tns,
    color=red,
    edgecolor=edgecol,
    linewidth=line_width,
)
ont_tns_bar = axS.bar(
    ont_positions,
    ont_tns,
    bar_width,
    color=purple,
    edgecolor=edgecol,
    linewidth=line_width,
)
ont_fps_bar = axS.bar(
    ont_positions,
    ont_fps,
    bar_width,
    bottom=ont_tns,
    color=red,
    edgecolor=edgecol,
    linewidth=line_width,
    label="FP",
)

labels = [drug_abbrev[d] for d in drugs]
label_pos = [(x + y) / 2 for x, y in zip(ill_positions, ont_positions)]
plt.xticks(label_pos, labels, rotation=90)
axR.set_ylabel("samples")
axR.set_xticks(label_pos)
axR.set_xticklabels(axS.get_xticklabels(), rotation=90)
axR.set_title("Resistant")
axS.set_title("Susceptible")

axS.legend(loc="best", prop={"size": 11})
leghandles, leglabels = axR.get_legend_handles_labels()
# leghandles.insert(2, leghandles[1])
# leglabels.insert(2, "TPs")
axR.legend(leghandles, leglabels, loc="best", prop={"size": 11})
sns.despine()
plt.tight_layout()

# %%
fig.savefig(snakemake.output.pheno_concordance_plot)

# %%
counts = clf_df.groupby(["drug", "technology", "classification"])["sample"].count()
drugs = sorted(set(clf_df["drug"]))
technologies = ["illumina", "nanopore"]
fps = [
    counts[d, t, "FP"] if (d, t, "FP") in counts else 0
    for d, t in product(drugs, technologies)
]
fns = [
    counts[d, t, "FN"] if (d, t, "FN") in counts else 0
    for d, t in product(drugs, technologies)
]
tns = [
    counts[d, t, "TN"] if (d, t, "TN") in counts else 0
    for d, t in product(drugs, technologies)
]
tps = [
    counts[d, t, "TP"] if (d, t, "TP") in counts else 0
    for d, t in product(drugs, technologies)
]
table = summary.set_index(["drug", "tech", "metric"])["value"].unstack().reset_index()
for k in ["drug", "tech"]:
    table[k] = table[k].str.capitalize()
table["FP"] = fps
table["FN"] = fns
table["TP"] = tps
table["TN"] = tns
table.fillna("-", inplace=True)
summary_cols = ["drug", "tech", "PPV", "NPV", "FNR", "FPR", "TP", "TN", "FN", "FP"]
table = table[summary_cols]
table.rename(columns={"tech": "technology"}, inplace=True)

# %% [markdown]
# This table summarises the results visualised above in Figure 2

# %%
rows = []
ci_str = (
    lambda tup: f"{tup[0]:.1%} ({tup[1]*100:.1f}-{tup[2]:.1%})"
    if tup[0] is not None
    else "-"
)
for i, row in table.iterrows():
    cm = ConfusionMatrix(tp=row["TP"], fp=row["FP"], tn=row["TN"], fn=row["FN"])
    npv = cm.npv()
    ppv = cm.ppv()
    vme = cm.fnr()
    me = cm.fpr()
    fn_str = f"{cm.fn}({cm.num_positive()})"
    fp_str = f"{cm.fp}({cm.num_negative()})"
    rows.append(
        (
            row["drug"].capitalize(),
            row["technology"],
            fn_str,
            fp_str,
            ci_str(vme),
            ci_str(me),
            ci_str(ppv),
            ci_str(npv),
        )
    )
pretty_cols = [
    "Drug",
    "Technology",
    "FN(R)",
    "FP(S)",
    "FNR(95% CI)",
    "FPR(95% CI)",
    "PPV(95% CI)",
    "NPV(95% CI)",
]
table = pd.DataFrame(rows, columns=pretty_cols)
table
# Out:
#             Drug Technology  FN(R)   FP(S)         FNR(95% CI)  \
# 0       Amikacin   Illumina  2(11)   2(77)   18.2% (5.1-47.7%)
# 1       Amikacin   Nanopore  0(11)   2(77)    0.0% (0.0-25.9%)
# 2    Capreomycin   Illumina   0(0)   1(51)                   -
# 3    Capreomycin   Nanopore   0(0)   1(51)                   -
# 4     Ethambutol   Illumina  3(14)  16(76)   21.4% (7.6-47.6%)
# 5     Ethambutol   Nanopore  4(14)  14(76)  28.6% (11.7-54.6%)
# 6      Isoniazid   Illumina  8(50)   3(48)   16.0% (8.3-28.5%)
# 7      Isoniazid   Nanopore  7(50)   7(48)   14.0% (7.0-26.2%)
# 8      Kanamycin   Illumina   0(0)   1(51)                   -
# 9      Kanamycin   Nanopore   0(0)   1(51)                   -
# 10     Ofloxacin   Illumina  0(10)   4(76)   0.0% (-0.0-27.8%)
# 11     Ofloxacin   Nanopore  0(10)   4(76)   0.0% (-0.0-27.8%)
# 12    Rifampicin   Illumina  5(47)   1(44)   10.6% (4.6-22.6%)
# 13    Rifampicin   Nanopore  6(47)   1(44)   12.8% (6.0-25.2%)
# ...

# %% [markdown]
# ## Table 1 Comparison of drug resistance predictions with culture-based phenotype
#
# For this comparison, we assume the drug susceptibility testing phenotype is correct and evaluate mykrobe Illumina and Nanopore resistance predictions accordingly. Pyrazinamide and Moxifloxacin are excluded as phenotype information is only available for 1 sample.
#
# FN=false negative; R=number of resistant samples; FP=false positive; S=number of susceptible samples; FNR=false negative rate; FPR=false positive rate; PPV=positive predictive value; NPV=negative predictive value; CI=Wilson score confidence interval

# %%
print(table.to_markdown(index=False))
# Out:
# | Drug         | Technology   | FN(R)   | FP(S)   | FNR(95% CI)        | FPR(95% CI)        | PPV(95% CI)        | NPV(95% CI)          |
# |:-------------|:-------------|:--------|:--------|:-------------------|:-------------------|:-------------------|:---------------------|
# | Amikacin     | Illumina     | 2(11)   | 2(77)   | 18.2% (5.1-47.7%)  | 2.6% (0.7-9.0%)    | 81.8% (52.3-94.9%) | 97.4% (91.0-99.3%)   |
# | Amikacin     | Nanopore     | 0(11)   | 2(77)   | 0.0% (0.0-25.9%)   | 2.6% (0.7-9.0%)    | 84.6% (57.8-95.7%) | 100.0% (95.1-100.0%) |
# | Capreomycin  | Illumina     | 0(0)    | 1(51)   | -                  | 2.0% (0.3-10.3%)   | 0.0% (0.0-79.3%)   | 100.0% (92.9-100.0%) |
# | Capreomycin  | Nanopore     | 0(0)    | 1(51)   | -                  | 2.0% (0.3-10.3%)   | 0.0% (0.0-79.3%)   | 100.0% (92.9-100.0%) |
# | Ethambutol   | Illumina     | 3(14)   | 16(76)  | 21.4% (7.6-47.6%)  | 21.1% (13.4-31.5%) | 40.7% (24.5-59.3%) | 95.2% (86.9-98.4%)   |
# ...

# %%
table.to_csv(snakemake.output.pheno_concordance_csv, na_rep="-", index=False)

# %%
clf_df
# Out:
#         sample       drug classification technology  coverage
# 0     mada_1-7  ofloxacin             TN   illumina     60.00
# 1     mada_1-7  ofloxacin             TN   nanopore     40.33
# 2     mada_1-7  isoniazid             TP   illumina     60.00
# 3     mada_1-7  isoniazid             TP   nanopore     40.33
# 4     mada_1-7  kanamycin             TN   illumina     60.00
# ...        ...        ...            ...        ...       ...
# 1285    R20983   amikacin             TN   nanopore    134.27
# 1286    R26778  ofloxacin             TN   illumina     60.00
# 1287    R26778  ofloxacin             TN   nanopore     80.19
# 1288    R26778   amikacin             TP   illumina     60.00
# 1289    R26778   amikacin             TP   nanopore     80.19
#
# [1290 rows x 5 columns]

# %%
coverages = np.arange(start=25, stop=155, step=5)

# %%
data = []

step = 10
tech = "nanopore"
start = round_down_to_base(
    clf_df.query("technology==@tech")["coverage"].min(), base=step
)
stop = (
    round_up_to_base(clf_df.query("technology==@tech")["coverage"].max(), base=step)
    + step
)
coverages = np.arange(start=start, stop=stop, step=step)
for i, covg in enumerate(coverages[:-1]):
    next_cov = coverages[i + 1]
    subdf = clf_df.query(
        "coverage > @covg and coverage <= @next_cov and technology == @tech"
    )
    s = subdf.value_counts(subset="classification")
    cm = ConfusionMatrix.from_series(s)
    total = sum(cm.ravel())
    data.append((covg, "FP", cm.fp / total, tech, total))
    data.append((covg, "TP", cm.tp / total, tech, total))
    data.append((covg, "FN", cm.fn / total, tech, total))
    data.append((covg, "TN", cm.tn / total, tech, total))

summary = pd.DataFrame(
    data, columns=["coverage", "classification", "proportion", "technology", "total"]
)


tech = "illumina"
start = round_down_to_base(
    clf_df.query("technology==@tech")["coverage"].min(), base=step
)
stop = round_up_to_base(clf_df.query("technology==@tech")["coverage"].max(), base=step)
coverages = np.arange(start=start, stop=stop, step=step)
for i, covg in enumerate(coverages[:-1]):
    next_cov = coverages[i + 1]
    subdf = clf_df.query(
        "coverage > @covg and coverage <= @next_cov and technology == @tech"
    )
    s = subdf.value_counts(subset="classification")
    cm = ConfusionMatrix.from_series(s)
    total = sum(cm.ravel())
    data.append((covg, "FP", cm.fp / total, tech, total))
    data.append((covg, "TP", cm.tp / total, tech, total))
    data.append((covg, "FN", cm.fn / total, tech, total))
    data.append((covg, "TN", cm.tn / total, tech, total))

summary = pd.DataFrame(
    data, columns=["coverage", "classification", "proportion", "technology", "total"]
)  # .melt(id_vars=["drug", "tool", "nanopore_covg"], var_name="metric")

# %% [markdown]
# Effect of Nanopore read depth on mykrobe phenotype prediction. Each point indicates the proportion (y-axis) of classifications of that type at the read depth (x-axis). Read depth is "binned". That is, read depth 40 is all samples with a read depth greater than 40 and less than or equal to 50. FP - false positive; TN - true negative; etc.

# %%
with sns.plotting_context(rc={"lines.linewidth": 1.1}):
    fig, ax = plt.subplots(nrows=1, figsize=(13, 8), dpi=300)
    x = "coverage"
    y = "proportion"
    hue = "classification"
    tech = "nanopore"
    linestyles = ["solid", "dotted", "dashed", "dashdot"]
    data = summary.query("technology == @tech")
    sns.pointplot(
        data=data,
        x=x,
        y=y,
        hue=hue,
        ax=ax,
        linestyles=linestyles,
        alpha=0.9,
    )
    xlabels = ax.get_xticklabels()
    xlabels[-1].set_text(xlabels[-1].get_text() + "+")
    ax.set_xticklabels(xlabels)
    ax.set_xlabel("read depth")

    ax2 = ax.twinx()
    sns.barplot(data=data, x=x, y="total", ax=ax2, color=blue, alpha=0.2)
    ax2.set_ylabel("number of samples")
    xlabels = ax2.get_xticklabels()
    xlabels[-1].set_text(xlabels[-1].get_text() + "+")
    ax2.set_xticklabels(xlabels)

# %%
fig.savefig(snakemake.output.pheno_coverage_plot)

# %% [markdown]
# # Concordance of mykrobe Nanopore resistance prediction with Illumina
# Having proven mykrobe's ability to predict resistance for select drugs with ONT, we look at the concordance of ONT-based predictions with Illumina-based ones. We aim to answer to main questions here: 1) Are ONT predictions concordant with Illumina and 2) does ONT depth of coverage impact prediction capabilities and, if so, what is the coverage threshold for this impact?
# We will also discuss the causes for any discrepencies and look to COMPASS/bcftools calls for adjudication if possible.
#
# For the figure/table of this section it might suffice to just have a table like the one in Table 1. of the recent mykrobe paper with a row for each drug and columns showing TPs, FNs etc. along with VME (95% CI), ME (95% CI), PPV and NPV

# %%
classes = sorted(set(calls["classification"]))
drugs = sorted(set(calls["drug"]))
conf_mxs = defaultdict(dict)

for drug in drugs:
    s = calls.query("drug == @drug").value_counts(subset=["classification"])
    cm = ConfusionMatrix.from_series(s)
    conf_mxs[drug] = cm

metrics = []
for drug, cm in conf_mxs.items():
    #     sensitivity = cm.sensitivity()
    #     specificity = cm.specificity()
    ppv = cm.ppv()[0]
    npv = cm.npv()[0]
    vme = cm.fnr()[0]
    me = cm.fpr()[0]
    metrics.append((drug, ppv, npv, vme, me))

summary_cols = ["drug", "PPV", "NPV", "FNR", "FPR"]

summary = pd.DataFrame(metrics, columns=summary_cols).melt(
    id_vars=["drug"], var_name="metric"
)

counts = calls.groupby(["drug", "classification"])["sample"].count()
fps = [counts[d, "FP"] if (d, "FP") in counts else 0 for d in drugs]
fns = [counts[d, "FN"] if (d, "FN") in counts else 0 for d in drugs]
tns = [counts[d, "TN"] if (d, "TN") in counts else 0 for d in drugs]
tps = [counts[d, "TP"] if (d, "TP") in counts else 0 for d in drugs]
table = summary.set_index(["drug", "metric"])["value"].unstack().reset_index()
table = table[summary_cols]
table["FP"] = fps
table["FN"] = fns
table["TP"] = tps
table["TN"] = tns
table
# Out:
# metric           drug       PPV       NPV       FNR       FPR  FP  FN  TP   TN
# 0            Amikacin  0.857143  1.000000  0.000000  0.014493   2   0  12  136
# 1         Capreomycin  0.857143  1.000000  0.000000  0.014493   2   0  12  136
# 2       Ciprofloxacin  1.000000  0.992537  0.058824  0.000000   0   1  16  133
# 3          Ethambutol  1.000000  0.968750  0.052632  0.000000   0   3  54   93
# 4           Isoniazid  0.919540  1.000000  0.000000  0.100000   7   0  80   63
# 5           Kanamycin  0.866667  1.000000  0.000000  0.014599   2   0  13  135
# 6        Moxifloxacin  1.000000  0.992537  0.058824  0.000000   0   1  16  133
# 7           Ofloxacin  1.000000  1.000000  0.000000  0.000000   0   0  17  133
# 8        Pyrazinamide  1.000000  0.991667  0.032258  0.000000   0   1  30  119
# 9          Rifampicin  1.000000  0.986111  0.012658  0.000000   0   1  78   71
# 10       Streptomycin  0.956522  0.980769  0.043478  0.019231   2   2  44  102

# %%
print(table.to_markdown(index=False))
# Out:
# | drug          |      PPV |      NPV |       FNR |       FPR |   FP |   FN |   TP |   TN |
# |:--------------|---------:|---------:|----------:|----------:|-----:|-----:|-----:|-----:|
# | Amikacin      | 0.857143 | 1        | 0         | 0.0144928 |    2 |    0 |   12 |  136 |
# | Capreomycin   | 0.857143 | 1        | 0         | 0.0144928 |    2 |    0 |   12 |  136 |
# | Ciprofloxacin | 1        | 0.992537 | 0.0588235 | 0         |    0 |    1 |   16 |  133 |
# | Ethambutol    | 1        | 0.96875  | 0.0526316 | 0         |    0 |    3 |   54 |   93 |
# | Isoniazid     | 0.91954  | 1        | 0         | 0.1       |    7 |    0 |   80 |   63 |
# | Kanamycin     | 0.866667 | 1        | 0         | 0.0145985 |    2 |    0 |   13 |  135 |
# | Moxifloxacin  | 1        | 0.992537 | 0.0588235 | 0         |    0 |    1 |   16 |  133 |
# | Ofloxacin     | 1        | 1        | 0         | 0         |    0 |    0 |   17 |  133 |
# ...

# %%
rows = []
ci_str = (
    lambda tup: f"{tup[0]:.1%} ({tup[1]*100:.1f}-{tup[2]:.1%})"
    if tup[0] is not None
    else "-"
)
for i, row in table.iterrows():
    cm = ConfusionMatrix(tp=row["TP"], fp=row["FP"], tn=row["TN"], fn=row["FN"])
    npv = cm.npv()
    ppv = cm.ppv()
    vme = cm.fnr()
    me = cm.fpr()
    fn_str = f"{cm.fn}({cm.num_positive()})"
    fp_str = f"{cm.fp}({cm.num_negative()})"
    rows.append(
        (row["drug"], fn_str, fp_str, ci_str(vme), ci_str(me), ci_str(ppv), ci_str(npv))
    )
pretty_cols = [
    "Drug",
    "FN(R)",
    "FP(S)",
    "FNR(95% CI)",
    "FPR(95% CI)",
    "PPV(95% CI)",
    "NPV(95% CI)",
]
table = pd.DataFrame(rows, columns=pretty_cols)
table
# Out:
#              Drug  FN(R)   FP(S)       FNR(95% CI)        FPR(95% CI)  \
# 0        Amikacin  0(12)  2(138)  0.0% (0.0-24.2%)    1.4% (0.4-5.1%)
# 1     Capreomycin  0(12)  2(138)  0.0% (0.0-24.2%)    1.4% (0.4-5.1%)
# 2   Ciprofloxacin  1(17)  0(133)  5.9% (1.0-27.0%)    0.0% (0.0-2.8%)
# 3      Ethambutol  3(57)   0(93)  5.3% (1.8-14.4%)    0.0% (0.0-4.0%)
# 4       Isoniazid  0(80)   7(70)   0.0% (0.0-4.6%)  10.0% (4.9-19.2%)
# 5       Kanamycin  0(13)  2(137)  0.0% (0.0-22.8%)    1.5% (0.4-5.2%)
# 6    Moxifloxacin  1(17)  0(133)  5.9% (1.0-27.0%)    0.0% (0.0-2.8%)
# 7       Ofloxacin  0(17)  0(133)  0.0% (0.0-18.4%)    0.0% (0.0-2.8%)
# 8    Pyrazinamide  1(31)  0(119)  3.2% (0.6-16.2%)    0.0% (0.0-3.1%)
# 9      Rifampicin  1(79)   0(71)   1.3% (0.2-6.8%)    0.0% (0.0-5.1%)
# 10   Streptomycin  2(46)  2(104)  4.3% (1.2-14.5%)    1.9% (0.5-6.7%)
#
#              PPV(95% CI)           NPV(95% CI)
# 0     85.7% (60.1-96.0%)  100.0% (97.3-100.0%)
# ...

# %% [markdown]
# ## Table 2 Comparison of Nanopore drug resistance predictions with Illumina predictions
#
# For this comparison, we assume the mykrobe resistance prediction from Illumina data is correct and evaluate the Nanopore prediction accordingly.
#
# FN=false negative; R=number of resistant samples; FP=false positive; S=number of susceptible samples; FNR=false negative rate; FPR=false positive rate; PPV=positive predictive value; NPV=negative predictive value; CI=Wilson score confidence interval

# %%
print(table.to_markdown(index=False))
# Out:
# | Drug          | FN(R)   | FP(S)   | FNR(95% CI)      | FPR(95% CI)       | PPV(95% CI)          | NPV(95% CI)          |
# |:--------------|:--------|:--------|:-----------------|:------------------|:---------------------|:---------------------|
# | Amikacin      | 0(12)   | 2(138)  | 0.0% (0.0-24.2%) | 1.4% (0.4-5.1%)   | 85.7% (60.1-96.0%)   | 100.0% (97.3-100.0%) |
# | Capreomycin   | 0(12)   | 2(138)  | 0.0% (0.0-24.2%) | 1.4% (0.4-5.1%)   | 85.7% (60.1-96.0%)   | 100.0% (97.3-100.0%) |
# | Ciprofloxacin | 1(17)   | 0(133)  | 5.9% (1.0-27.0%) | 0.0% (0.0-2.8%)   | 100.0% (80.6-100.0%) | 99.3% (95.9-99.9%)   |
# | Ethambutol    | 3(57)   | 0(93)   | 5.3% (1.8-14.4%) | 0.0% (0.0-4.0%)   | 100.0% (93.4-100.0%) | 96.9% (91.2-98.9%)   |
# | Isoniazid     | 0(80)   | 7(70)   | 0.0% (0.0-4.6%)  | 10.0% (4.9-19.2%) | 92.0% (84.3-96.0%)   | 100.0% (94.3-100.0%) |
# | Kanamycin     | 0(13)   | 2(137)  | 0.0% (0.0-22.8%) | 1.5% (0.4-5.2%)   | 86.7% (62.1-96.3%)   | 100.0% (97.2-100.0%) |
# ...

# %%
table.to_csv(snakemake.output.illumina_concordance_csv, na_rep="-", index=False)
