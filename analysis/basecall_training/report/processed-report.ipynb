# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/mnt/snakemake', '/hps/nobackup/research/zi/projects/tech_wars/analysis/basecall_training/report']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x99\x1d\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cBresults/evaluation/guppy/mada_132.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_132.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_104.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_104.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_101.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_101.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_130.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_130.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_116.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_116.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_125.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_125.tubby.assembly_error_details.tsv\x94\x8cCresults/evaluation/guppy/mada_1-44.guppy.assembly_error_details.tsv\x94\x8cCresults/evaluation/tubby/mada_1-44.tubby.assembly_error_details.tsv\x94\x8cBresults/evaluation/guppy/mada_102.guppy.assembly_error_details.tsv\x94\x8cBresults/evaluation/tubby/mada_102.tubby.assembly_error_details.tsv\x94\x8c>results/evaluation/guppy/mada_132.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_132.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_104.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_104.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_101.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_101.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_130.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_130.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_116.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_116.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_125.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_125.tubby.consensus_identity.csv\x94\x8c?results/evaluation/guppy/mada_1-44.guppy.consensus_identity.csv\x94\x8c?results/evaluation/tubby/mada_1-44.tubby.consensus_identity.csv\x94\x8c>results/evaluation/guppy/mada_102.guppy.consensus_identity.csv\x94\x8c>results/evaluation/tubby/mada_102.tubby.consensus_identity.csv\x94\x8c9results/evaluation/guppy/mada_132.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_132.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_104.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_104.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_101.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_101.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_130.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_130.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_116.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_116.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_125.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_125.tubby.read_identity.csv\x94\x8c:results/evaluation/guppy/mada_1-44.guppy.read_identity.csv\x94\x8c:results/evaluation/tubby/mada_1-44.tubby.read_identity.csv\x94\x8c9results/evaluation/guppy/mada_102.guppy.read_identity.csv\x94\x8c9results/evaluation/tubby/mada_102.tubby.read_identity.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x0easm_error_tsvs\x94K\x00K\x10\x86\x94\x8c\x17consensus_identity_csvs\x94K\x10K \x86\x94\x8c\x12read_identity_csvs\x94K K0\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94ehE\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(hK)}\x94\x8c\x05_name\x94hEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bh=h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ch\rh\x0eh\x0fh\x10h\x11h\x12h\x13h\x14h\x15h\x16h\x17h\x18h\x19e}\x94(h;}\x94hC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bubh?hV)\x81\x94(h\x1ah\x1bh\x1ch\x1dh\x1eh\x1fh h!h"h#h$h%h&h\'h(h)e}\x94(h;}\x94hC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bubhAhV)\x81\x94(h*h+h,h-h.h/h0h1h2h3h4h5h6h7h8h9e}\x94(h;}\x94hC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bubub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x18report/read-identity.png\x94\x8c\x1creport/read-relative-len.png\x94\x8c\x1freport/read-identity-vs-len.png\x94\x8c\x1dreport/consensus-identity.png\x94\x8c!report/consensus-relative-len.png\x94\x8c report/consensus-error-types.png\x94\x8c)report/combined_identity_relative_len.png\x94e}\x94(h;}\x94(\x8c\rread_identity\x94K\x00N\x86\x94\x8c\x11read_relative_len\x94K\x01N\x86\x94\x8c\x14read_identity_vs_len\x94K\x02N\x86\x94\x8c\x12consensus_identity\x94K\x03N\x86\x94\x8c\x16consensus_relative_len\x94K\x04N\x86\x94\x8c\x0berror_types\x94K\x05N\x86\x94\x8c\rcombined_plot\x94K\x06N\x86\x94uhC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bh\x88h\x7fh\x8ah\x80h\x8ch\x81h\x8eh\x82h\x90h\x83h\x92h\x84h\x94h\x85ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(\x8c\x06ggplot\x94\x8c\x04Set1\x94K\rK\x08\x86\x94M,\x01J\xa0\x86\x01\x00e}\x94(h;}\x94(\x8c\x05style\x94K\x00N\x86\x94\x8c\x07palette\x94K\x01N\x86\x94\x8c\x07figsize\x94K\x02N\x86\x94\x8c\x03dpi\x94K\x03N\x86\x94\x8c\tsubsample\x94K\x04N\x86\x94uhC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bh\xa8h\xa3h\xaah\xa4h\xach\xa5h\xaeM,\x01h\xb0J\xa0\x86\x01\x00ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94}\x94(h;}\x94hC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01M\x00\x08e}\x94(h;}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06mem_mb\x94K\x02N\x86\x94uhC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bh\xd1K\x01h\xd3K\x01h\xd5M\x00\x08ub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\x1dreport/processed-report.ipynb\x94a}\x94(h;}\x94\x8c\x08notebook\x94K\x00N\x86\x94shC]\x94(hEhFehEhIhK\x85\x94R\x94(hK)}\x94hOhEsNt\x94bhFhIhK\x85\x94R\x94(hK)}\x94hOhFsNt\x94bh\xe7h\xe4ub\x8c\x06config\x94}\x94(\x8c\x08data_dir\x94\x8c1/hps/nobackup/research/zi/projects/tech_wars/data\x94\x8c\x06outdir\x94\x8c\x07results\x94\x8c\x0cmodel_config\x94\x8c\x1edna_r9.4.1_450bps_hac_prom.cfg\x94\x8c\x0freport_notebook\x94\x8c\x16report/report.py.ipynb\x94\x8c\x08min_covg\x94G?\xe9\x99\x99\x99\x99\x99\x9a\x8c\x05model\x94\x8cPresources/pretrained_models/guppy-gpu.v3-4-5.template_r9.4.1_450bps_hac_prom.jsn\x94\x8c\x04seed\x94KX\x8c\rtraining_size\x94G?\xc9\x99\x99\x99\x99\x99\x9a\x8c\x15model_training_params\x94}\x94(\x8c\x05model\x94\x8c\x1ftaiyaki/models/mGru_flipflop.py\x94\x8c\rchunk_len_min\x94M\xd0\x07\x8c\rchunk_len_max\x94M\xa0\x0f\x8c\x04size\x94M\x00\x01\x8c\x06stride\x94K\x02\x8c\x06winlen\x94K\x13\x8c\x08num_gpus\x94K\x02\x8c\x12base_learning_rate\x94G?`bM\xd2\xf1\xa9\xfcu\x8c\x05fast5\x94}\x94(\x8c\x05indir\x94\x8c\x07pathlib\x94\x8c\tPosixPath\x94\x93\x94(\x8c\x01/\x94\x8c\x03nfs\x94\x8c\tresearch1\x94\x8c\x02zi\x94\x8c\x08projects\x94\x8c\ttech_wars\x94\x8c\x04data\x94\x8c\nmadagascar\x94\x8c\x08nanopore\x94\x8c\x08raw_data\x94t\x94R\x94\x8c\x06outdir\x94j\x11\x01\x00\x00j\x18\x01\x00\x00\x8c\x06fast5s\x94\x86\x94R\x94\x8c\nbatch_size\x94M\xa0\x0f\x8c\x04trim\x94}\x94(\x8c\x05start\x94K\xc8\x8c\x03end\x94Kduu\x8c\ncontainers\x94}\x94(\x8c\x05conda\x94\x8c&docker://continuumio/miniconda3:4.7.12\x94\x8c\x07taiyaki\x94\x8c*library://mbhall88/default/taiyaki:ce0cfbf\x94\x8c\x05fast5\x94\x8c8docker://quay.io/biocontainers/ont-fast5-api:3.0.1--py_0\x94\x8c\tguppy-gpu\x94\x8c*library://mbhall88/default/guppy-gpu:3.4.5\x94\x8c\x07rebaler\x94\x8c2docker://quay.io/biocontainers/rebaler:0.2.0--py_1\x94u\x8c\x04envs\x94}\x94(\x8c\taln_tools\x94\x8c\x13envs/aln_tools.yaml\x94\x8c\x03paf\x94\x8c\renvs/paf.yaml\x94\x8c\x04chop\x94\x8c\x0eenvs/chop.yaml\x94\x8c\x06mummer\x94\x8c\x10envs/mummer.yaml\x94\x8c\x06report\x94\x8c\x10envs/report.yaml\x94u\x8c\x07scripts\x94}\x94(\x8c\rread_identity\x94\x8c\x1ascripts/read_assessment.py\x94\x8c\rchop_assembly\x94\x8c\x18scripts/chop_assembly.py\x94\x8c\rerror_summary\x94\x8c\x18scripts/error_summary.py\x94u\x8c\nassemblies\x94}\x94(\x8c\x08mada_101\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_101/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_102\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_102/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_104\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_104/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_116\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_116/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_125\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_125/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_130\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_130/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\x08mada_132\x94\x8c\x7f/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_132/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94\x8c\tmada_1-44\x94\x8c\x80/hps/nobackup/research/zi/projects/tech_wars/analysis/assembly/results/mada_1-44/flye/pacbio/polished_assembly.flye.pacbio.fasta\x94uu\x8c\x04rule\x94\x8c\x06report\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cN/hps/nobackup/research/zi/projects/tech_wars/analysis/basecall_training/report\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir('/hps/nobackup/research/zi/projects/tech_wars/analysis/basecall_training');
######## snakemake preamble end #########

# %%
from pathlib import Path
from typing import Tuple, Optional
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import random
import string

plt.style.use(snakemake.params.style)
sns.set_palette(snakemake.params.palette)
FIGSIZE = snakemake.params.figsize
DPI = snakemake.params.dpi

# %%
def draw(
    data: pd.DataFrame, 
    x: str, 
    y: str, 
    title: str,
    xtitle: Optional[str] = None,
    ytitle: Optional[str] = None,
    hue: Optional[str] = None, 
    ylim: Optional[Tuple[int, int]] = None
):
    fig, ax = plt.subplots(figsize=FIGSIZE, dpi=DPI)
    sns.boxenplot(
        x=x, 
        y=y, 
        hue=hue, 
        data=data, 
    )
    
    if ylim:
        ax.set_ylim(ylim)
        
    ax.set_title(title)
    
    if xtitle:
        ax.set_xlabel(xtitle)
        
    if ytitle:
        ax.set_ylabel(ytitle)
        
    ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax.grid(b=True, which='major', linewidth=0.75, alpha=1.0)
    ax.grid(b=True, which='minor', linewidth=0.5, alpha=0.5)
        
    return fig, ax

# %% [markdown]
# # Read BLAST identity

# %%
read_identity_files = snakemake.input.read_identity_csvs
print(f"{len(read_identity_files)} CSV files")
# Out:
# 16 CSV files

# %%
frames = []
for csvfile in map(Path, read_identity_files):
    df = pd.read_csv(csvfile)
    sample, model = csvfile.name.split(".")[:2]
    df["sample"] = sample
    df["model"] = model
    frames.append(df)
read_data = pd.concat(frames)

# %% [markdown]
# Here we plot the [BLAST identity][blast] for each read. Each sample has been grouped together into one violin plot per basecalling model. To get the BLAST identity, we basecalled the reads with the respective model and mapped those basecalls to the "truth" assembly. To calculate the BLAST identity for each mapping, we take the number of matching bases divided by the length of the alignment. For more information, refer to [this][pafpy-blast] implementation.
#
# The Y-axis of the plot has been "zoomed in" to get a better sense of how the models compare.
#
# [blast]: https://lh3.github.io/2018/11/25/on-the-definition-of-sequence-identity#blast-identity
# [pafpy-blast]: https://pafpy.xyz/pafrecord.html#pafpy.pafrecord.PafRecord.blast_identity

# %%
title = "Read-level accuracy"
xtitle = "Basecalling model"
ytitle = "BLAST identity"
ylim = (0.7, 1.0)
x = "model"
y = "identity"
fig, ax = draw(read_data, x=x, y=y, ylim=ylim, title=title, xtitle=xtitle, ytitle=ytitle)

# %%
fig.savefig(snakemake.output.read_identity)

# %% [markdown]
# ## Summary statistics

# %%
read_data.groupby(x)[y].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# model
# guppy  1047829.0  0.906699  0.048019  0.418569  0.883826  0.920168  0.941614
# tubby  1047508.0  0.929516  0.040221  0.461869  0.912879  0.941470  0.957413
#
#        max
# model
# guppy  1.0
# tubby  1.0

# %% [markdown]
# # Relative read length

# %% [markdown]
# We define relative read length as the length of the *aligned* part of the read, divided by the total length of the read. The purpose of this metric is to see whether there is a bias towards insertions (greater than 1.0) or deletions (less than 1.0).

# %%
title = "Relative read length"
xtitle = "Basecalling model"
ytitle = "Relative length"
ylim = (0.85, 1.1)
x = "model"
y = "relative_len"
fig, ax = draw(read_data, x=x, y=y, ylim=ylim, title=title, xtitle=xtitle, ytitle=ytitle)

# %%
fig.savefig(snakemake.output.read_relative_len)

# %% [markdown]
# ## Summary statistics

# %%
read_data.groupby(x)[y].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# model
# guppy  1047829.0  0.991860  0.023972  0.455827  0.984218  0.993194  1.001440
# tubby  1047508.0  0.976374  0.023877  0.493556  0.969833  0.982176  0.989214
#
#             max
# model
# guppy  1.988124
# tubby  1.894910

# %% [markdown]
# # Read length against read identity

# %%
N = snakemake.params.subsample
sub_df = read_data.iloc[random.sample(range(len(read_data)), N)]

# %%
x = "read_len"
xtitle = "Read length (bp)"
y = "identity"
ytitle = "BLAST identity"
title = "Read length against identity"

log_ticks = [1, 100, 500, 1e3, 2e3, 3e3, 5e3, 1e4]
xlim = (0, log_ticks[-1])
ylim = (0.7, 1.0)

jplot = sns.jointplot(
    data=sub_df,
    x=x, 
    y=y, 
    hue="model",
    kind="hist",
    alpha=0.8, 
    height=FIGSIZE[0],
)
_ = jplot.ax_joint.set(xticks=log_ticks, xlim=xlim, ylabel=ytitle, xlabel=xtitle, ylim=ylim)
_ = plt.xticks(rotation=45)

# %%
jplot.savefig(snakemake.output.read_identity_vs_len, dpi=DPI)

# %% [markdown]
# # Consensus accuracy
# Here we show consensus accuracy in a similar manner to read identity. Each "read" in this context is a result of chopping the [`rebaler`](https://github.com/rrwick/Rebaler) assembly of the reads up into 10Kbps "chunks" to simulate reads, and then mapping those chunks back to the original assembly using `minimap2` (and the `-x asm5` preset).

# %%
consensus_identity_files = snakemake.input.consensus_identity_csvs
print(f"{len(consensus_identity_files)} CSV files")
# Out:
# 16 CSV files

# %%
frames = []
for csvfile in map(Path, consensus_identity_files):
    df = pd.read_csv(csvfile)
    sample, model = csvfile.name.split(".")[:2]
    df["sample"] = sample
    df["model"] = model
    df["type"] = "consensus"
    frames.append(df)

consensus_data = pd.concat(frames)

# %%
title = "Consensus-level accuracy"
xtitle = "Basecalling model"
ytitle = "BLAST identity"
ylim = (0.996, 1.0001)
x = "model"
y = "identity"
fig, ax = draw(consensus_data, x=x, y=y, ylim=ylim, title=title, xtitle=xtitle, ytitle=ytitle)

# %%
fig.savefig(snakemake.output.consensus_identity)

# %% [markdown]
# ## Summary statistics

# %%
consensus_data.groupby(x)[y].describe()
# Out:
#         count      mean       std       min       25%     50%     75%  max
# model
# guppy  3531.0  0.998735  0.004426  0.863455  0.998801  0.9992  0.9995  1.0
# tubby  3532.0  0.998971  0.004102  0.862996  0.999001  0.9993  0.9995  1.0

# %% [markdown]
# # Relative "read" length for consensus chunks

# %%
title = "Relative consensus length"
xtitle = "Basecalling model"
ytitle = "Relative length"
ylim = (0.997, 1.002)
x = "model"
y = "relative_len"
fig, ax = draw(consensus_data, x=x, y=y, ylim=ylim, title=title, xtitle=xtitle, ytitle=ytitle)

# %%
fig.savefig(snakemake.output.consensus_relative_len)

# %% [markdown]
# ## Summary statistics

# %%
consensus_data.groupby(x)[y].describe()
# Out:
#         count      mean       std       min       25%     50%     75%  \
# model
# guppy  3531.0  0.999500  0.004806  0.950751  0.999101  0.9994  0.9996
# tubby  3532.0  0.999495  0.004466  0.969556  0.999101  0.9994  0.9996
#
#             max
# model
# guppy  1.156337
# tubby  1.156470

# %% [markdown]
# ## Combined identity and relative length plots

# %%
fig, axes = plt.subplots(figsize=FIGSIZE, dpi=DPI, nrows=2, ncols=2, sharex=True)

# read identity
ax = axes[0][0]  # top left
title = "Read-level accuracy"
xtitle = ""
ytitle = "BLAST identity"
ylim = (0.7, 1.0)
x = "model"
y = "identity"
sns.boxenplot(x=x, y=y, data=read_data, ax=ax)
ax.set(ylim=ylim, title=title, xlabel=xtitle, ylabel=ytitle)
    
# read relative length
ax = axes[1][0]  # bottom left
title = "Relative read length"
xtitle = "Basecalling model"
ytitle = "Relative length"
ylim = (0.85, 1.1)
y = "relative_len"
sns.boxenplot(x=x, y=y, data=read_data, ax=ax)

ax.set(ylim=ylim, title=title, xlabel=xtitle, ylabel=ytitle)
    
# consensus identity
ax = axes[0][1]  # top right
title = "Consensus-level accuracy"
xtitle = ""
ytitle = "BLAST identity"
ylim = (0.996, 1.0001)
y = "identity"
sns.boxenplot(x=x, y=y, data=consensus_data, ax=ax)
ax.set(ylim=ylim, title=title, xlabel=xtitle, ylabel=ytitle)

# consensus relative length
ax = axes[1][1]  # bottom right
title = "Relative consensus length"
xtitle = "Basecalling model"
ytitle = "Relative length"
ylim = (0.997, 1.002)
y = "relative_len"
sns.boxenplot(x=x, y=y, data=consensus_data, ax=ax)

ax.set(ylim=ylim, title=title, xlabel=xtitle, ylabel=ytitle)

for n, ax in enumerate(axes.flat):
    ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
    ax.grid(b=True, which='major', linewidth=0.75, alpha=1.0)
    ax.grid(b=True, which='minor', linewidth=0.5, alpha=0.5)
    ax.text(-0.1, 1.1, string.ascii_uppercase[n], transform=ax.transAxes, size=20, weight='bold')

# %%
fig.savefig(snakemake.output.combined_plot)

# %% [markdown]
# # Consensus error types
# Here we classify the types of errors that occur in the assemblies and look at how these errors compare across models. The errors are per-assembly, so the confidence intervals represent to variation in error types between samples/assemblies.

# %%
error_files = snakemake.input.asm_error_tsvs
print(f"{len(error_files)} TSV files")
# Out:
# 16 TSV files

# %%
frames = []
for csvfile in map(Path, error_files):
    df = pd.read_csv(csvfile, sep="\t")
    sample, model = csvfile.name.split(".")[:2]
    df["sample"] = sample
    df["model"] = model
    df["type"] = "consensus"
    frames.append(df)

id_vars = ["sample", "model", "type", "assembly"]
value_vars = ["dcm", "homo_del", "homo_ins", "other_del", "other_ins", "sub"]
data = pd.concat(frames).melt(id_vars=id_vars, value_vars=value_vars, var_name="error_type")

# %%
x = "error_type"
y = "value"
hue = "model"
kind = "bar"
plot = sns.catplot(
    data=data, 
    x=x, 
    y=y, 
    hue=hue, 
    kind=kind, 
    height=8, 
    aspect=1.5, 
    errwidth=1.5, 
    capsize=0.1
)
plot.set_xlabels("Error type")
plot.set_ylabels("Consensus error rate (%)")
plot.set(title="Consensus errors per model")
plot.ax.get_yaxis().set_minor_locator(mpl.ticker.AutoMinorLocator())
plot.ax.grid(b=True, which='major', linewidth=0.75)
plot.ax.grid(b=True, which='minor', linewidth=0.5, alpha=0.5)
plot.fig.set_dpi(DPI)

# %%
plot.fig.savefig(snakemake.output.error_types)

# %% [markdown]
# ## Summary statistics

# %%
data.groupby([hue, x]).describe()
# Out:
#                  value                                                    \
#                  count      mean       std       min       25%       50%
# model error_type
# guppy dcm          8.0  0.000059  0.000091  0.000010  0.000021  0.000027
#       homo_del     8.0  0.001770  0.003181  0.000449  0.000562  0.000651
#       homo_ins     8.0  0.000054  0.000041  0.000006  0.000033  0.000046
#       other_del    8.0  0.000204  0.000140  0.000023  0.000127  0.000148
#       other_ins    8.0  0.000067  0.000049  0.000005  0.000042  0.000059
#       sub          8.0  0.000085  0.000070  0.000012  0.000041  0.000065
# tubby dcm          8.0  0.000038  0.000064  0.000009  0.000013  0.000017
#       homo_del     8.0  0.001506  0.002706  0.000412  0.000498  0.000575
#       homo_ins     8.0  0.000015  0.000010  0.000002  0.000008  0.000015
#       other_del    8.0  0.000308  0.000291  0.000057  0.000165  0.000224
#       other_ins    8.0  0.000020  0.000035  0.000003  0.000004  0.000008
# ...
